# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/practica_v_dllo_pto_math_infancia/blob/main/5_caracterizacion/1_taller_caracterizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/practica_v_dllo_pto_math_infancia/blob/main/5_caracterizacion/1_taller_caracterizacion.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso:  ]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = ''>

# %% [markdown]
# Reconocimiento a las profesoras destacadas en enseñanza de la matemática en Colombia

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/infantil.xlsx'
estudiantes = pd.read_excel(path)
estudiantes.index = range(1, len(estudiantes) + 1)
estudiantes.head(3)
# Out:
#        Cedula                            Nombre                         Email  \
# 1  1063787015        ALVAREZ PEREZ CARLOS JULIO  carlos.alvarez19@udea.edu.co
# 2  1032248705              ARRIETA LOPEZ ELIANA         e.arrieta@udea.edu.co
# 3  1038646812  CARCAMO TABORDA MARCELA PATRICIA   marcela.carcamo@udea.edu.co
#
#    Asistencia
# 1         NaN
# 2         NaN
# 3         NaN

# %%
# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def asistencia():
    global lista_estudiantes
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Asistió {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        # Validación de entrada
        if asistencia == 'n':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Asistencia'] += 4
            print(f"""Actualizado: {estudiante_aleatorio} 
                  ahora tiene {estudiantes.at[indice, 'Asistencia']} en la columna 'Asistencia'.""")
        
        elif asistencia != 's':
            print("Entrada inválida. Por favor, introduce 's' para sí o 'n' para no.")
            return  # Volver a preguntar para el mismo estudiante si la entrada es inválida
        
        # Remover al estudiante de la lista para no llamarlo de nuevo
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Función para guardar cambios al final de la sesión
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
while lista_estudiantes:
    asistencia()

# Guardar los cambios una vez que todos los estudiantes hayan sido llamados
guardar_cambios()
# Out:
# Llamando a ORTIZ PERDOMO HEVIZ YULIZA...
# Actualizado: ORTIZ PERDOMO HEVIZ YULIZA
#                   ahora tiene nan en la columna 'Asistencia'.
# Llamando a MURILLO CUELLO LICETH PAOLA...
# Actualizado: MURILLO CUELLO LICETH PAOLA
#                   ahora tiene nan en la columna 'Asistencia'.
# Llamando a CARCAMO TABORDA MARCELA PATRICIA...
# Actualizado: CARCAMO TABORDA MARCELA PATRICIA
#                   ahora tiene nan en la columna 'Asistencia'.
# Llamando a DIAZ ESTRADA MAYERLIS...
# Actualizado: DIAZ ESTRADA MAYERLIS
#                   ahora tiene nan en la columna 'Asistencia'.
# Llamando a QUIROZ ACOSTA KATHERINE...
# Actualizado: QUIROZ ACOSTA KATHERINE
#                   ahora tiene nan en la columna 'Asistencia'.
# Llamando a POLO MARTINEZ ADRIANA MARIA...
# Actualizado: POLO MARTINEZ ADRIANA MARIA
#                   ahora tiene nan en la columna 'Asistencia'.
# Llamando a ARRIETA LOPEZ ELIANA...
# Actualizado: ARRIETA LOPEZ ELIANA
# ...

# %% [markdown]
# # Principios de mi labor docente

# %% [markdown]
# ## Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# <img src = 'https://resources.maneuveringthemiddle.com/wp-content/uploads/2020/07/04212706/1-5.png' width = 200>

# %% [markdown]
# # Metodología de Aprendizaje Basado en Problemas  y Proyectos (ABPP)

# %% [markdown]
# <img src = 'https://www.unir.net/wp-content/uploads/2020/07/aprendizaje-problemas2-1-1-1-1.jpeg' width = 200>

# %% [markdown]
# # Desarrollo del pensamiento computacional con Lenguajes Python y R, y con archivos Markdown y .ipynb, orientado a la formación en ciencia de datos

# %% [markdown]
# <img src = 'https://i.ytimg.com/vi/mcG_wcR4e6M/maxresdefault.jpg' width = 200>

# %% [markdown]
# # Principio de fomento a la ciencia abierta, enseñar en el acceso a los datos públicos y el uso de software de código abierto

# %% [markdown]
# <img src = 'https://unesdoc.unesco.org/in/rest/Thumb/image?id=p%3A%3Ausmarcdef_0000379949_spa&author=UNESCO&title=Recomendaci%C3%B3n+de+la+UNESCO+sobre+la+Ciencia+Abierta&year=2021&publisher=UNESCO&TypeOfDocument=UnescoPhysicalDocument&mat=PGD&ct=true&size=512&isPhysical=1' width = 200>

# %% [markdown]
# El enfoque STEAMS en educación preescolar, primaria y secundaria es una extensión del enfoque STEM (Ciencia, Tecnología, Ingeniería y Matemáticas) y su variante STEAM, que incorpora el Arte.

# %% [markdown]
# El acrónimo STEAMS incluye:

# %% [markdown]
# 1. **Science (Ciencia):** Fomenta la curiosidad por el mundo natural y el desarrollo de habilidades científicas, como la observación, experimentación y análisis.

# %% [markdown]
# 2. **Technology (Tecnología):** Integra herramientas tecnológicas para potenciar el aprendizaje y la resolución de problemas, promoviendo la alfabetización digital desde edades tempranas.

# %% [markdown]
# 3. **Engineering (Ingeniería):** Introduce el pensamiento lógico y la resolución de problemas estructurados, fomentando habilidades como el diseño y la construcción de soluciones.

# %% [markdown]
# 4. **Arts (Arte):** Añade creatividad y pensamiento crítico, permitiendo a los estudiantes expresarse y explorar el aprendizaje a través de formas artísticas (plásticas, música, teatro).

# %% [markdown]
# 5. **Mathematics (Matemáticas):** Refuerza las habilidades numéricas y el razonamiento lógico, fundamentales en la resolución de problemas y comprensión de conceptos abstractos.

# %% [markdown]
# 6. **Social Sciences (Ciencias Sociales):** Incorpora la comprensión del entorno social, político, cultural y económico, promoviendo el desarrollo de la conciencia crítica sobre el mundo y su historia, además de habilidades de empatía y ciudadanía.

# %% [markdown]
# El enfoque STEAMS pretende desarrollar un aprendizaje **interdisciplinario** que integre estas áreas para fomentar un pensamiento más holístico y práctico.

# %% [markdown]
# Se busca que los estudiantes no solo aprendan conocimientos técnicos, sino también cómo aplicarlos creativa y críticamente en situaciones reales, promoviendo habilidades como el trabajo en equipo, la comunicación y la innovación.

# %% [markdown]
# En educación preescolar, primaria, secundaria y superior, se adapta a las diferentes etapas de desarrollo cognitivo y emocional de los estudiantes, promoviendo el aprendizaje activo y contextualizado.

# %% [markdown]
# <img src = 'https://www.campuseducacion.com/blog/wp-content/uploads/2023/03/foto01-1.jpg' width = 200>

# %% [markdown]
# # Qué estamos haciendo por la internalización en esta clase y este curso

# %% [markdown]
# Estas son mis acciones como docente de matemáticas en la Universidad de Antioquia con miras a la **internacionalización** de mi práctica docente y el desarrollo de competencias internacionales para mis estudiantes, ls cuales he estructurado con el siguiente enfoque:

# %% [markdown]
# ### 1. **Visión Global en la Formación Académica**

# %% [markdown]
#    - **Competencias Internacionales**: Asegúrate de que el contenido de tus cursos fomente habilidades que sean reconocidas globalmente.

# %% [markdown]
# Al educar a los estudiantes en **Python, LaTeX, Markdown y Jupyter Notebooks** y en la **introducción a la ciencia de datos y técnicas de Machine Learning**, estás proporcionando competencias altamente demandadas en los sectores tecnológicos y académicos a nivel internacional.

# %% [markdown]
#    - **Relevancia de los Contenidos**: Destaca cómo los temas que enseñas, como el **desarrollo del pensamiento computacional** y la **ciencia de datos**, están alineados con las necesidades globales actuales en diversas industrias, desde la tecnología hasta las ciencias naturales y sociales.

# %% [markdown]
#    - **Referencias a Estándares Internacionales**: Puedes vincular tu enseñanza a estándares internacionales de competencias en programación y ciencia de datos (por ejemplo, frameworks del **IEEE, ACM**, y estándares de la **data science** o la **computación en la nube**).

# %% [markdown]
# ### 2. **Innovación Pedagógica con Enfoque Internacional**

# %% [markdown]
#    - **Aula Invertida y ABP**: Presenta cómo tu enfoque de **aula invertida** y **aprendizaje basado en problemas (ABP)** permite a los estudiantes trabajar de manera autónoma y colaborativa, lo que los prepara para escenarios laborales internacionales que requieren autoaprendizaje y habilidades de resolución de problemas en equipo.

# %% [markdown]
#    - **Uso de Jupyter Notebooks**: El uso de **Jupyter Notebooks** en tus clases no solo facilita la **integración de código, matemáticas y texto**, sino que también es una plataforma utilizada globalmente en ambientes académicos y profesionales, lo que hace a tus estudiantes más competitivos internacionalmente.

# %% [markdown]
# ### 3. **Tecnología y Herramientas de Uso Global**

# %% [markdown]
#    - **Lenguaje Python**: Python es uno de los lenguajes de programación más usados a nivel mundial, tanto en la academia como en la industria.

# %% [markdown]
# Al formar a tus estudiantes en Python para ciencia de datos y machine learning, los preparas para operar en entornos tecnológicos globales.

# %% [markdown]
#    - **Herramientas de Ciencia Abierta**: Resalta cómo herramientas como **GitHub**, **Google Colab** y otras plataformas de código abierto están alineadas con el movimiento de **ciencia abierta**, el cual es internacionalmente reconocido y permite que los estudiantes colaboren y compartan proyectos a nivel global.

# %% [markdown]
# ### 4. **Investigación y Publicaciones Internacionales**

# %% [markdown]
#    - **Promoción de la Investigación**: Detalla cómo promueves que tus estudiantes participen en proyectos de **investigación aplicada**, con posibilidad de publicación en revistas internacionales. Esto contribuye a la reputación internacional de la Universidad de Antioquia.

# %% [markdown]
#    - **Colaboraciones Internacionales**: Si has colaborado con investigadores de otras instituciones o universidades en el extranjero, menciona estos proyectos y cómo han enriquecido tu enseñanza y proporcionado a los estudiantes una visión más globalizada.

# %% [markdown]
# ## 5. **Uso del Inglés para la Internacionalización**

# %% [markdown]
#    - **Comunicación Científica en Inglés**:

# %% [markdown]
# Fomentar el aprendizaje del inglés como lengua científica es clave para que tus estudiantes puedan acceder a publicaciones internacionales, conferencias, y material académico que no está disponible en español.

# %% [markdown]
# Esto es esencial para que adquieran competencias que les permitan desempeñarse en cualquier contexto internacional.

# %% [markdown]
#    - **Material Bilingüe**: Al generar material educativo en Python, LaTeX y Markdown, considera ofrecer algunos de estos recursos en inglés, para que los estudiantes se familiaricen con el vocabulario técnico y científico internacional.

# %% [markdown]
# ### 6. **Certificaciones y Estándares Internacionales**

# %% [markdown]
#    - **Participación en Certificaciones Internacionales**: Impulsa que los estudiantes busquen certificaciones internacionales en Python o ciencia de datos (como las ofrecidas por **Coursera, edX,** o **Google**).

# %% [markdown]
# Estas certificaciones no solo validan sus competencias, sino que también incrementan el reconocimiento de la Universidad de Antioquia en el contexto internacional.

# %% [markdown]
#    - **Alineación con Acreditaciones Internacionales**: Vincula tu trabajo docente con los estándares de acreditación y certificación que garantizan que la universidad siga siendo reconocida internacionalmente.

# %% [markdown]
# Puedes vincularte con organizaciones internacionales que promuevan la excelencia en la educación y tecnología, como **ABET** para la acreditación en ingeniería y ciencias computacionales.

# %% [markdown]
# ### 7. **Proyectos Abiertos y Ciencia Reproducible**

# %% [markdown]
#    - **GitHub y Open Science**: La utilización de **GitHub** para almacenar los proyectos y materiales de enseñanza en repositorios públicos permite que otros investigadores y educadores internacionales puedan revisar y replicar tu trabajo.

# %% [markdown]
# Esto contribuye a la creación de una red de colaboración científica abierta.

# %% [markdown]
#    - **Transparencia y Reproducibilidad**: La ciencia de datos y machine learning están profundamente ligados a la reproducibilidad.

# %% [markdown]
# Asegura que tus estudiantes desarrollen prácticas de transparencia y documentación en la investigación, que son pilares en la comunidad científica global.

# %% [markdown]
# ### 8. **Participación en Redes y Conferencias Internacionales**
#    - **Presentación en Conferencias Internacionales**: Destaca cómo tu participación en conferencias internacionales (como la **ASCOLFA** o eventos sobre educación en matemáticas) contribuye al prestigio de la universidad y permite que tus prácticas sean evaluadas y reconocidas a nivel global.

# %% [markdown]
#    - **Promoción de Estudiantes en Eventos Internacionales**: Impulsa la participación de tus estudiantes en competiciones internacionales de programación o hackathons, como los organizados por **Google**, **ACM** o **Kaggle**.

# %% [markdown]
# Esto no solo desarrolla sus habilidades, sino que también visibiliza el talento de la Universidad de Antioquia a nivel global.
#
# ---

# %% [markdown]
# Con esta estrategia, presento mis acciones docentes en términos de competencias internacionales, innovación pedagógica, tecnología, investigación y participación en redes globales, asegurando que mi práctica esté alineada con los estándares internacionales y que tus estudiantes estén preparados para competir en contextos internacionales.

# %% [markdown]
# ### **Metodología de Enseñanza: Aprendizaje Basado en Problemas y Proyectos (ABPP)**

# %% [markdown]
# El **Aprendizaje Basado en Problemas y Proyectos (ABPP)** es una metodología educativa que integra los enfoques del **Aprendizaje Basado en Problemas (ABP)** y el **Aprendizaje Basado en Proyectos (PBL, por sus siglas en inglés)**.

# %% [markdown]
# Es especialmente útil para la formación de futuros docentes, ingenieros y administradores, ya que combina el desarrollo de habilidades prácticas con el pensamiento crítico y reflexivo.

# %% [markdown]
# A continuación, se presenta una descripción adaptada a la enseñanza de las matemáticas en educación infantil, Licenciatura en Matemáticas, Ingeniería Agropecuaria y Administración de Empresas:
#
# ---

# %% [markdown]
# ### **1. Fundamentos del ABPP**

# %% [markdown]
# El ABPP se basa en:
# - **Resolución de Problemas Reales:** Los estudiantes analizan y resuelven problemas auténticos relacionados con su área de formación, fomentando la aplicación práctica del conocimiento.

# %% [markdown]
# - **Proyectos como Herramientas Integradoras:** Los proyectos permiten desarrollar habilidades interdisciplinarias y ofrecer soluciones concretas a los problemas planteados.

# %% [markdown]
# - **Aprendizaje Activo:** Los estudiantes son responsables de su aprendizaje y participan activamente en el proceso de investigación, diseño y solución.
#
# ---

# %% [markdown]
# ### **2. Aplicación del ABPP en Áreas Específicas**
#
# #### **Educación Infantil (Licenciatura en Educación Infantil)**
# - **Enfoque:** Desarrollo del pensamiento matemático en la infancia desde contextos lúdicos, familiares y culturales.

# %% [markdown]
# - **Problemas típicos:**
#   - ¿Cómo enseñar los números naturales mediante actividades prácticas y juegos?
#   - ¿Qué estrategias pueden emplearse para abordar el concepto de cantidad en edades tempranas?

# %% [markdown]
# - **Proyectos:** Diseño de secuencias didácticas que usen Python, Jupyter Notebooks y materiales manipulativos para enseñar matemáticas de forma interactiva.

# %% [markdown]
# - **Competencias desarrolladas:**
#   - Uso de herramientas tecnológicas para diseñar actividades educativas.
#   - Comprensión del desarrollo cognitivo infantil y su relación con las matemáticas.

# %% [markdown]
# #### **Licenciatura en Matemáticas**
# - **Enfoque:** Resolución de problemas matemáticos aplicados y profundización teórica en áreas como análisis matemático y modelado.

# %% [markdown]
# - **Problemas típicos:**
#   - ¿Cómo se pueden resolver ecuaciones diferenciales aplicadas a modelos físicos o económicos?
#   - ¿Cómo modelar fenómenos naturales mediante funciones matemáticas?

# %% [markdown]
# - **Proyectos:**
#   - Desarrollo de software educativo para explorar conceptos matemáticos.
#   - Aplicación de modelado matemático para resolver problemas reales en otras disciplinas.

# %% [markdown]
# - **Competencias desarrolladas:**
#   - Dominio de la matemática teórica y aplicada.
#   - Uso de tecnología para la enseñanza y la investigación.

# %% [markdown]
# #### **Ingeniería Agropecuaria**
# - **Enfoque:** Modelado matemático y análisis de datos para mejorar la producción agrícola y la gestión de recursos.
# - **Problemas típicos:**
#   - ¿Cómo modelar el crecimiento de cultivos considerando variables climáticas?
#   - ¿Cómo optimizar el uso del agua en sistemas de riego mediante análisis matemático?

# %% [markdown]
# - **Proyectos:**
#   - Desarrollo de modelos predictivos con Python y bibliotecas de aprendizaje automático.
#   - Implementación de proyectos que combinen matemáticas y ciencias de datos para resolver problemas agrícolas.

# %% [markdown]
# - **Competencias desarrolladas:**
#   - Integración de matemáticas con tecnologías avanzadas.
#   - Resolución de problemas agropecuarios mediante análisis y modelado.

# %% [markdown]
# #### **Administración de Empresas**

# %% [markdown]
# - **Enfoque:** Uso de las matemáticas y la ciencia de datos para la toma de decisiones estratégicas.
# - **Problemas típicos:**
#   - ¿Cómo identificar patrones de comportamiento del consumidor usando series de tiempo?
#   - ¿Qué estrategias matemáticas pueden optimizar la asignación de recursos en una empresa?

# %% [markdown]
# - **Proyectos:**
#   - Implementación de modelos de análisis financiero y simulaciones.
#   - Desarrollo de dashboards interactivos para la gestión de datos empresariales.

# %% [markdown]
# - **Competencias desarrolladas:**
#   - Habilidad para interpretar datos matemáticos en contextos de negocio.
#   - Capacidad para diseñar soluciones basadas en datos.

# %% [markdown]
# ### **3. Beneficios del ABPP**

# %% [markdown]
# - **Desarrollo de competencias clave:**
#   - Pensamiento crítico y creativo.
#   - Trabajo colaborativo.
#   - Comunicación efectiva.
#   - Uso de herramientas tecnológicas avanzadas.

# %% [markdown]
# - **Adaptación al contexto laboral:** Los estudiantes aprenden a enfrentar desafíos del mundo real y a diseñar soluciones prácticas y aplicables.
# - **Flexibilidad e interdisciplinariedad:** La metodología se adapta a diversas áreas, fomentando el aprendizaje integrado.
#
# ---

# %% [markdown]
# ### **4. Ejemplo General de Implementación**

# %% [markdown]
# 1. **Identificación del problema:** Se plantea un desafío concreto, como modelar el crecimiento poblacional de una comunidad rural (Ingeniería Agropecuaria) o diseñar una estrategia para enseñar fracciones a niños de 8 años (Educación Infantil).

# %% [markdown]
# 2. **Formación de equipos:** Los estudiantes trabajan en grupos, distribuyendo roles y tareas.
# 3. **Investigación y diseño:** Los estudiantes investigan el problema, proponen soluciones y diseñan un proyecto.

# %% [markdown]
# 4. **Implementación:** Se desarrolla el proyecto, como una herramienta tecnológica o una propuesta pedagógica.
# 5. **Evaluación:** Los estudiantes presentan sus resultados en un informe o una exposición, recibiendo retroalimentación de sus compañeros y docentes.
#
# ---

# %% [markdown]
# El ABPP es una metodología versátil que conecta el conocimiento teórico con la práctica, preparando a los estudiantes para los retos de sus profesiones en la enseñanza de la matemática, la ingeniería y la administración.

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# [Aprender a obtener el sí sin ceder]()

# %% [markdown]
# # Diferentes Metodologias activas para la clase de Formación de maestros de Licenciatura en Educación Infantil

# %% [markdown]
# Aquí tienes **5 metodologías innovadoras** para realizar tu taller de formación de maestros, combinando trabajo en parejas, grupos y aprendizaje activo sobre caracterización del contexto y diseño de prácticas pedagógicas para el pensamiento matemático:
#
# ---

# %% [markdown]
# ### **1. Método "Jigsaw" (Rompecabezas)**
# **Objetivo:** Construir colectivamente una guía de caracterización del contexto.
# **Actividades:**
# - **Parejas:** Cada pareja investiga un aspecto de la caracterización (ej: perfil socioeconómico, intereses infantiles, recursos del aula).
# - **Grupos (4-5 personas):** Reunirse para integrar la información en un mapa conceptual.
# - **Producto final:** Infografía colaborativa con estrategias para vincular el contexto al diseño de actividades matemáticas.
#
# **Herramienta:** Mural.co o póster físico con post-its.
#
# ---

# %% [markdown]
# ### **2. World Café**
# **Objetivo:** Reflexionar sobre cómo adaptar prácticas pedagógicas a distintos contextos.
# **Actividades:**
# - **Mesas temáticas (grupos de 4):** Cada mesa discute una pregunta (ej: *"¿Cómo identificar las ideas matemáticas informales de los niños en su juego libre?"*).
# - **Rotación:** Cada 15 minutos, un integrante queda como "anfitrión" y los demás rotan para enriquecer las respuestas.
# - **Parejas:** Al final, cada pareja diseña una actividad matemática basada en las conclusiones.
#
# **Material:** Hojas grandes para registrar ideas en cada mesa.
#
# ---

# %% [markdown]
# ### **3. Aprendizaje Basado en Retos (ABR)**
# **Objetivo:** Crear herramientas de diagnóstico contextual.
# **Actividades:**
# - **Reto inicial (grupos de 3):** *"Diseñen un instrumento para caracterizar las habilidades matemáticas de niños en un aula rural multigrado"*.
# - **Parejas:** Prototipado rápido (ej: entrevista lúdica, diario de observación).
# - **Presentación:** Cada grupo expone su herramienta y recibe feedback con la técnica *"2 estrellas y 1 deseo"* (2 aspectos positivos + 1 sugerencia).
#
# **Ejemplo de producto:** Rúbrica de observación con indicadores de pensamiento matemático.
#
# ---

# %% [markdown]
# ### **4. Role-Playing + Simulación**
# **Objetivo:** Practicar la observación y adaptación pedagógica.
# **Actividades:**
# - **Parejas:** Uno actúa como maestro que aplica una actividad matemática (ej: clasificación de objetos), el otro como niño con necesidades específicas (ej: dificultad en lenguaje).
# - **Grupos (6 personas):** Discuten cómo modificar la actividad según el perfil del "niño".
# - **Plenaria:** Socialización de ajustes pedagógicos.
#
# **Recurso:** Videos cortos de niños reales en actividades matemáticas (para análisis grupal).
#
# ---

# %% [markdown]
# ### **5. Método "Design Thinking"**
# **Objetivo:** Diseñar prácticas pedagógicas centradas en el niño.
# **Fases:**
# 1. **Empatizar (parejas):** Entrevistas simuladas para identificar necesidades de los niños.
# 2. **Definir (grupos):** Sintetizar hallazgos (ej: *"Los niños aprenden mejor con materiales concretos de su entorno"*).
# 3. **Prototipar (grupos):** Crear una actividad matemática usando solo recursos locales (ej: semillas, piedras).
# 4. **Testear (parejas):** Un maestro implementa la actividad, el otro observa y registra.
#
# **Producto:** Kit de actividades matemáticas contextualizadas.
#
# ---

# %% [markdown]
# ### **Elementos Clave para Todas las Metodologías**
# - **Documentación:** Portafolio digital con fotos, videos y reflexiones.
# - **Técnicas de cierre:**
#   - *"El semáforo"*: Verde (lo aprendido), amarillo (dudas), rojo (dificultades).
#   - *"Tweet ficticio"*: Resumir en 140 caracteres una idea clave.
#
# **Duración sugerida:** 4 horas (2 sesiones de 2h con breaks activos).
#
# ---

# %% [markdown]
# ### **Ejemplo de Actividad Concreta**
# **Nombre:** *"El Mapa Matemático de Nuestra Escuela"*
# - **Parejas:** Identifican espacios físicos de la escuela donde emergen conceptos matemáticos (ej: escaleras → secuencias numéricas).
# - **Grupos:** Diseñan una secuencia didáctica usando esos espacios.
# - **Producto:** Mapa interactivo con códigos QR que vinculan lugares a actividades matemáticas.

# %% [markdown]
# ---
#
# Estas metodologías promueven **aprendizaje colaborativo, reflexión crítica y aplicación práctica**, esenciales para que los maestros vinculen la caracterización del contexto con el diseño de prácticas pedagógicas efectivas.

# %% [markdown]
# # Taller: Cómo realizar la caracterización del contexto y de los niños en la Práctica Pedagófica V para Educación Infantil

# %% [markdown]
# ## Documentos a tener en cuenta en esta Práctica Pedagógica V
#
# 1. [DBA de Matemáticas](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.colombiaaprende.edu.co/sites/default/files/files_public/2022-06/DBA_Matematicas-min.pdf)
# 2. [Lineamientos Curriculares Matemáticas](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.mineducacion.gov.co/1621/articles-89869_archivo_pdf9.pdf)
# 3. [Estándares Básicos de Competencias en Lenguaje, Matemáticas, Ciencias y Ciudadanas](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.colombiaaprende.edu.co/sites/default/files/files_public/2022-06/Estandares_basicos_competencias-min.pdf)

# %% [markdown]
# # Estructura general para todas las clases
#
# Dame, por favor, un diseño de Taller, con el enfoque: Aula Invertida, STEAMS y de Aprendizaje Basado en Problemas y Proyectos (ABPP) sobre: "Taller para formación de Maestros sobre: Cómo realizar la caracterización del contexto y de los niños en la Práctica Pedagógica V para Educación Infantil" siguiendo la estructura:
#
# 1. Metodología del Taller: **5. Método "Design Thinking"**
# **Objetivo:** Diseñar prácticas pedagógicas centradas en el niño.
#     **Fases:**
#     1. **Empatizar (parejas):** Entrevistas simuladas para identificar necesidades de los niños.
#     2. **Definir (grupos):** Sintetizar hallazgos (ej: *"Los niños aprenden mejor con materiales concretos de su entorno"*).
#     3. **Prototipar (grupos):** Crear una actividad matemática usando solo recursos locales (ej: semillas, piedras).
#     4. **Testear (parejas):** Un maestro implementa la actividad, el otro observa y registra.
#
#     **Producto:** Kit de actividades matemáticas contextualizadas.
#
# 2. Título del taller.
#
# 3. Objetivos de aprendizaje que incluyan los indicadores del logro de estos
#    objetivos.
#
# 4. Contenido de la taller. Incluye el formato para entregar el informe de
#    Caracterización en la práctica V en el Liceo Caucasia
#
# 5. Un mapa conceptual que resuma la clase elaborado en Graphviz de Python con nodos y edges de diferentes formas, colores y rellenos y renderizado en la siguiente ubicación: `"C:\Users\marco\Downloads"`. No olvides el parámetro `view = True` ppara el método `render()` de `Graphviz`.
#
# 6. Elementos históricos y epistemológicos relevantes para la clase y enunciados con ilustraciones para niños de 8 años.
#
# 7. Actividades de aprendizaje que incluyan componente lúdico, cotidiano y artístico.
#
# 8. Incluye una canción o un poema que ayude a interiorizar y fijar los conceptos asociados a esta clase.
#
# 9.  Tarea o actividades de ejercitación y fijación.
#
# 10. Evaluación incluyendo diez proyectos, un ejemplo de quiz (de tres preguntas) y un ejemplo de parcial (De cinco preguntas).
#
# 11. Diseño de actividad de retroalimentación.
#
# 12. Dame un vocabulario y frases del idioma inglés asociadas a esta clase.
#
# 13.   Incluye apéndice para la clase sobre desarrollo de habilidades para trabajar en equipo y de asertividad y empatía para relacionarnos. También elementos de la inteligencia emocional para presentar pruebas sin temor y sin realizar fraude en ellas. Elementos de la inteligencia Emocional para comportarnos en clase de manera no reactiva y muy asertiva, con trato amable y constructiva.
#
# 14. Incluye 10 referentes en didáctica de la matemática que estén de acuerdo a la propuesta didáctica de este taller. Adiciona a estos referentes a Raymond Duval (Representaciones y cambios de representación para la adquisición de conceptos matemáticos) y a Jeannette Wing (Desarrollo del pensamiento computacional). Déjame todos estos referentes ordenados de acuerdo a las normas APA. Déjame todos estos referentes ordenados de acuerdo a las normas APA. Incluye las citaciones a estos referentes a medida que vallas diseñando la clase.
#
# Pero  que este diseño sea para que el estudiante pueda aprender experimentando en cuadernos Jupyter con funciones de usuario y animaciones y visualizaciones en python. En particular utiliza NumPy, Pandas, Sympy, Matplotlib.pyplot, plotly, Seaborn, matplotlib.animation, ipywidgets. Cada vez que itilice `matplotlib.animacion` no olvides incluir el uso de IPython. display para la rederización de estas animaciones a través de Jupyter Notebook. No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dolar $ para que VS Code si me renderice estas expresiones del lenguaje latex.
#
# En particular utiliza NumPy, Pandas, Sympy, Matplotlib.pyplot, plotly, Seaborn, matplotlib.animation, ipywidgets.
#
# Cada vez que itilice `matplotlib.animacion` no olvides incluir el uso de `IPython. display` para la renderización de estas animaciones a través de Jupyter Notebook. No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dólar $ para que VS Code si me renderice estas expresiones del lenguaje Latex.

# %%
path_image = r'C:/Users/marco/Downloads'
def save_fig(nombre_archivo_imagen):
    import os 
    import matplotlib.pyplot as plt 
    imagen_path = os.path.join(path_image, nombre_archivo_imagen)
    plt.savefig(imagen_path, bbox_inches='tight')

# %% [markdown]
# # Taller para Formación de Maestros: Caracterización del Contexto y de los Niños en la Práctica Pedagógica V para Educación Infantil
#
# ## 1. Metodología del Taller:
# ### **Método "Design Thinking"**
# **Objetivo:** Diseñar prácticas pedagógicas centradas en el niño.
# **Fases:**
# 1. **Empatizar (parejas):** Entrevistas simuladas para identificar necesidades de los niños.
# 2. **Definir (grupos):** Sintetizar hallazgos (*Ejemplo: "Los niños aprenden mejor con materiales concretos de su entorno"*).
# 3. **Prototipar (grupos):** Crear una actividad matemática usando solo recursos locales (*Ejemplo: semillas, piedras*).
# 4. **Testear (parejas):** Un maestro implementa la actividad, el otro observa y registra.
#
# **Producto:** Kit de actividades matemáticas contextualizadas.

# %% [markdown]
# ## 2. Título del Taller
# **Caracterización del Contexto y de los Niños en la Práctica Pedagógica V para Educación Infantil**
#
# ## 3. Objetivos de Aprendizaje
# - Identificar y analizar el contexto social, económico y cultural de los niños.
# - Aplicar metodologías activas para la caracterización del contexto en educación infantil.
# - Diseñar estrategias didácticas basadas en la información recolectada.
#
# **Indicadores de logro:**
# - Realiza entrevistas y observaciones de forma estructurada.
# - Sintetiza hallazgos relevantes para la enseñanza infantil.
# - Diseña actividades didácticas adaptadas al contexto.

# %% [markdown]
# ## 4. Contenido del Taller
# - **Introducción a la caracterización del contexto y los niños.**
# - **Metodologías para el levantamiento de información.**
# - **Uso de herramientas computacionales (Python en Jupyter Notebooks) para analizar y visualizar datos.**
# - **Diseño de estrategias didácticas contextualizadas.**
#
# **Formato para entrega del informe:**
# 1. Datos generales del niño.
# 2. Contexto familiar y socioeconómico.
# 3. Intereses y necesidades del niño.
# 4. Análisis y reflexión.
# 5. Propuesta de intervención.

# %% [markdown]
# ## 5. Mapa Conceptual (Graphviz en Python)
# **Ubicación de renderizado:** `C:\Users\marco\Downloads`

# %%
from graphviz import Digraph
import os

dot = Digraph(comment='Mapa Conceptual del Taller', format='png')
dot.node('A', 'Caracterización', shape='box', style='filled', fillcolor='lightblue')
dot.node('B', 'Contexto', shape='ellipse', style='filled', fillcolor='lightyellow')
dot.node('C', 'Metodologías', shape='diamond', style='filled', fillcolor='lightgreen')
dot.edge('A', 'B')
dot.edge('A', 'C')
dot.render(view=True, directory='C:\\Users\\marco\\Downloads')
# Out:
# 'C:\\Users\\marco\\Downloads\\Digraph.gv.png'

# %% [markdown]
# ## 6. Elementos Históricos y Epistemológicos
# - Historia de la educación infantil y la importancia de la contextualización.
# - Ilustraciones sobre cómo los niños aprenden en diferentes contextos.

# %% [markdown]
# ## 7. Actividades de Aprendizaje
# - Juego de roles en entrevistas.
# - Representación artística del contexto infantil.
# - Actividad lúdica de análisis de datos en Python.

# %% [markdown]
# ## 8. Canciones y Poemas
# - **"Aprendamos con el entorno"** (canción infantil sobre la importancia del contexto).

# %% [markdown]
# ## 9. Tareas y Actividades de Fijación
# - Aplicación de entrevistas y análisis de datos.
# - Implementación de una estrategia didáctica basada en el contexto.

# %% [markdown]
# ## 10. Evaluación
# **Ejemplo de quiz:**
# 1. ¿Qué elementos componen la caracterización del contexto infantil?
# 2. ¿Cómo puede influir el contexto en el aprendizaje de los niños?
# 3. ¿Qué herramientas de Python se pueden usar para analizar datos en educación infantil?

# %% [markdown]
# ## 11. Retroalimentación
# - Discusión en grupos sobre los aprendizajes obtenidos.
# - Reflexión sobre la aplicabilidad en la práctica docente.

# %% [markdown]
# ## 12. Vocabulario y Frases en Inglés
# - "Educational context" (Contexto educativo)
# - "Child-centered teaching" (Enseñanza centrada en el niño)

# %% [markdown]
# ## 13. Apéndice sobre Habilidades de Trabajo en Equipo e Inteligencia Emocional
# - **Trabajo en equipo:** Empatía, comunicación efectiva, respeto.
# - **Inteligencia emocional en evaluaciones:** Manejo del estrés, honestidad académica.

# %% [markdown]
# ## 14. Referencias en Didáctica de la Matemática
# **Ejemplo en APA:**
# - Duval, R. (2006). Representaciones y cambios de representación para la adquisición de conceptos matemáticos. *Educational Studies in Mathematics, 63*(2), 103-131.
# - Wing, J. M. (2006). Computational thinking. *Communications of the ACM, 49*(3), 33-35.
#
# _(Se incluirán 10 referentes adicionales)._

# %% [markdown]
# ---
# Este diseño de taller promueve el aprendizaje experiencial en Jupyter Notebooks mediante la aplicación de Python para la visualización y análisis de datos en la caracterización del contexto infantil.

# %% [markdown]
# [Video de apoyo a la lectura de la estructura de esta clase]()

# %% [markdown]
# # Implementación de esta estructura de taller
#
# # Taller para Formación de Maestros: Caracterización del Contexto y de los Niños en la Práctica Pedagógica V para Educación Infantil
#
# ## 1. Metodología del Taller:
# ### **Método "Design Thinking"**
# **Objetivo:** Diseñar prácticas pedagógicas centradas en el niño.
# **Fases:**
# 1. **Empatizar (parejas):** Entrevistas simuladas para identificar necesidades de los niños.
# 2. **Definir (grupos):** Sintetizar hallazgos (*Ejemplo: "Los niños aprenden mejor con materiales concretos de su entorno"*).
# 3. **Prototipar (grupos):** Crear una actividad matemática usando solo recursos locales (*Ejemplo: semillas, piedras*).
# 4. **Testear (parejas):** Un maestro implementa la actividad, el otro observa y registra.
#
# **Producto:** Kit de actividades matemáticas contextualizadas.
#
# ## 2. Título del Taller
# **Caracterización del Contexto y de los Niños en la Práctica Pedagógica V para Educación Infantil**
#
# ## 3. Objetivos de Aprendizaje
# - Identificar y analizar el contexto social, económico y cultural de los niños.
# - Aplicar metodologías activas para la caracterización del contexto en educación infantil.
# - Diseñar estrategias didácticas basadas en la información recolectada.
#
# **Indicadores de logro:**
# - Realiza entrevistas y observaciones de forma estructurada.
# - Sintetiza hallazgos relevantes para la enseñanza infantil.
# - Diseña actividades didácticas adaptadas al contexto.
#
# ## 4. Contenido del Taller
# - **Introducción a la caracterización del contexto y los niños.**
# - **Metodologías para el levantamiento de información.**
# - **Uso de herramientas computacionales (Python en Jupyter Notebooks) para analizar y visualizar datos.**
# - **Diseño de estrategias didácticas contextualizadas.**

# %% [markdown]
# # **Formato para entrega del informe:**

# %% [markdown]
# ## Prompt para el diseño del formati de caracterización
#
# Genérame, por favor, el formato de caracterización, que los practicantes que acompaño y lidero este semestre en práctica pedagógica V,  deben realizar. Para luego escoger tres enfoques pedagógicos, que consideren más apropiados o aplicables a la intervención investigativa que van a hacer con niños de grados: preescolar, primero, segundo o tercero de primaria en Colombia. Por favor, diseña el formato de caracterización de acuerdo a la siguiente rúbrica de caracterización "# **Rúbrica para la Caracterización de la Práctica Pedagógica V: Desarrollo del Pensamiento Matemático en Preescolar, 1°, 2° y 3°**
# Son 8 horas de caracterización. Es decir, deben realizarla en dos jueves de visita al Liceo Caucasia.
# ---
# Fecha de entrega de la caracterizaciín: 18 de Abril de 2025.
#
#
# ### **Criterios de Evaluación**
# La rúbrica evalúa los siguientes aspectos clave, alineados con los objetivos del curso y la etapa de *caracterización* descrita en el programa:
#
# | **Criterio** | **Excelente (4.5-5.0)** | **Bueno (4.0-4.4)** | **Suficiente (3.5-3.9)** | **Insuficiente (0.0-3.4)** |
# |--------------|--------------------------|----------------------|---------------------------|----------------------------|
# | **1. Análisis del contexto institucional y del PEI** | Identifica de manera exhaustiva los elementos del PEI y el plan de estudios relacionados con matemáticas. Incluye políticas institucionales, enfoques pedagógicos y recursos disponibles. | Describe los elementos del PEI y el plan de estudios, pero con omisiones menores en políticas o recursos. | Menciona superficialmente el PEI y el plan de estudios sin profundizar en su relación con las matemáticas. | No incluye información relevante del PEI o el plan de estudios. |
# | **2. Diagnóstico de concepciones y prácticas docentes** | Analiza críticamente las metodologías, estrategias y materiales usados por los docentes para enseñar matemáticas. Incluye evidencias (entrevistas, observaciones). | Describe las prácticas docentes con ejemplos, pero sin análisis profundo o evidencias claras. | Menciona las prácticas docentes sin contextualizar o relacionarlas con la teoría. | No aborda las prácticas docentes o presenta información irrelevante. |
# | **3. Evaluación de actitudes y habilidades matemáticas de los estudiantes** | Identifica con precisión las actitudes, habilidades y dificultades de los estudiantes mediante instrumentos válidos (encuestas, observaciones, diario pedagógico). Relaciona los hallazgos con teorías de desarrollo cognitivo (ej. Piaget). | Describe actitudes y habilidades de los estudiantes, pero con limitaciones en los instrumentos usados o en la relación con la teoría. | Menciona actitudes y habilidades sin evidencias claras o fundamentación teórica. | No utiliza instrumentos ni presenta datos relevantes sobre los estudiantes. |
# | **4. Identificación de necesidades y desafíos** | Detecta necesidades y desafíos específicos del contexto (ej. falta de materiales, baja motivación, brechas cognitivas) y propone soluciones innovadoras alineadas con los DBA y Estándares. | Identifica necesidades generales, pero las soluciones propuestas son poco concretas o desvinculadas de los referentes curriculares. | Menciona necesidades sin profundizar en su origen o posibles soluciones. | No identifica desafíos relevantes o presenta propuestas incoherentes. |
# | **5. Integración de referentes teóricos** | Vincula de manera crítica los Lineamientos Curriculares, Estándares, DBA y bases teóricas (ej. pensamiento numérico, lógico) con el contexto analizado. Cita fuentes académicas. | Menciona los referentes teóricos, pero con conexiones limitadas al contexto práctico. | Incluye referentes teóricos sin contextualizarlos o aplicarlos al diagnóstico. | Omite referentes teóricos o los usa de manera incorrecta. |
# | **6. Redacción y organización del informe** | El informe es coherente, estructurado y creativo (ej. uso de gráficos, tablas). Cumple con normas APA y evita errores gramaticales. | El informe está bien organizado, pero con algunos errores formales o falta de elementos visuales. | El informe carece de estructura clara o presenta errores formales recurrentes. | El informe es desorganizado, con errores graves de redacción o formato. |
#
# ---
#
# ### **Indicadores Adicionales**
# - **Instrumentos utilizados:** Diario pedagógico, observaciones, entrevistas, encuestas, revisión documental.
# - **Creatividad:** Uso de formatos innovadores (infografías, videos, mapas conceptuales).
# - **Reflexión crítica:** Capacidad de cuestionar prácticas y proponer mejoras basadas en la teoría.
# - **Conexión con la ruralidad (si aplica):** Análisis de desafíos específicos en contextos rurales (ej. acceso a recursos, diversidad cultural).
#
# ---
#
# ### **Ponderación**
# - **Total:** 5% de la calificación final del curso (según el programa adjunto).
# - **Fecha de entrega:** Tercera semana después del inicio de la práctica.
#
# ---
#
# ### **Recomendaciones**
# - Utilizar los documentos rectores del MEN (Lineamientos Curriculares, Estándares, DBA).
# - Incluir evidencias fotográficas, transcripciones de entrevistas o fragmentos del diario pedagógico.
# - Relacionar el diagnóstico con los ejes del curso: formativo, disciplinar e investigativo.
#
# **Nota:** Esta rúbrica integra los requerimientos del programa de Práctica Pedagógica V, enfocándose en la articulación teoría-práctica y el desarrollo del pensamiento matemático en las infancias.
#
#
#
# # Evaluación
# |Descripción|Fecha Límite de Entrega|Porcentaje|
# |-----------|-----------------------|----------|
# |Presentación en video de los tres enfoques escogidos|4 de abril|2|
# |Caracterización|24 de abril|5%| " ; y orientando a los practicantes a elegir los tres enfoques pedagógicos a implementar de la siguiente lista de 11 enfoques: # 11 enfoques pedagógicos para el desarrollo del pensamiento matemático en la infancia, contextualizados al Liceo Caucasia (Antioquia) y alineados con los objetivos de la Práctica Pedagógica V de la Universidad de Antioquia:
#
# ---
#
# Fecha de entrega de el video sobre los enfoques pedagógicos: **4 de abril de 2025**
#
#
# ### 1. **Aprendizaje Basado en Juegos (ABJ)**
# **Descripción:** Integrar juegos estructurados (como loterías numéricas, rompecabezas geométricos o juegos de roles con monedas locales, bloques lógicos)
# para desarrollar conceptos matemáticos.
# **Justificación:** Promueve el aprendizaje lúdico, alineado con los procesos sensoriomotores y preoperacionales de las infancias.
# **Contexto Caucasia:** Usar materiales autóctonos (semillas de maíz, hojas de plátano para clasificar) y juegos tradicionales (como "la lleva" adaptada a secuencias numéricas).
#
# #### Ejemplo de utilización de este enfoque:
#
#
# ---
#
# ### 2. **Enfoque Sociocultural con Pertinencia Local**
# **Descripción:** Vincular las matemáticas a prácticas culturales y económicas de la región (ej. contar cosechas, medir terrenos, analizar precios del mercado local).
# **Justificación:** Alinea con el eje sociocultural del curso y los Lineamientos Curriculares del MEN.
# **Aplicación:** Proyectos sobre la economía caucasiana (ej. calcular ganancias en ventas de plátano o pescado del Río Cauca).
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ---
#
# ### 3. **Resolución de Problemas Cotidianos**
# **Descripción:** Plantear problemas reales del entorno (ej. distribuir alimentos en la escuela, medir distancias entre veredas).
# **Justificación:** Desarrolla competencias para "saber hacer", como propone la Revolución Educativa.
# **Ejemplo:** Analizar la frecuencia de lluvias en el municipio para introducir estadística básica.
#
# #### Ejemplo de utilización de este enfoque:
#
#
# ---
#
# ### 4. **Manipulación de Material Concreto con Recursos Locales**
# **Descripción:** Usar objetos tangibles (piedras del río, botones reciclados, mazorcas) para operaciones básicas y geometría.
# **Justificación:** Favorece la etapa sensoriomotora y operacional concreta, clave en preescolar y primeros grados.
# **Contexto:** Talleres con arcilla para modelar figuras 3D, inspiradas en la artesanía local.
#
# #### Ejemplo de utilización de este enfoque:
#
#
# ---
#
# ### 5. **Proyectos de Aula con Enfoque Investigativo**
# **Descripción:** Diseñar secuencias didácticas basadas en preguntas de los niños (ej. "¿Cuántas frutas crecen en un árbol del colegio?").
# **Justificación:** Fortalece el eje investigativo del curso, vinculando observación y sistematización.
# **Aplicación:** Registrar datos de cultivos en huertas escolares para gráficos simples.
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ---
#
# ### 6. **Modelación Matemática con Contextos Rurales**
# **Descripción:** Representar matemáticamente situaciones del campo (ej. patrones en tejidos de hamacas, trayectorias de animales).
# **Justificación:** Alinea con los Derechos Básicos de Aprendizaje (DBA) y el componente métrico-geométrico.
# **Ejemplo:** Crear mapas a escala del colegio usando pasos y palmos como unidades de medida.
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ---
#
# ### 7. **Pensamiento Visible a través del Arte**
# **Descripción:** Usar dibujos, murales o danzas para expresar conceptos matemáticos (ej. simetría en pinturas, ritmos numéricos en música vallenata).
# **Justificación:** Integra el desarrollo afectivo y social, como propone la educación inicial.
# **Contexto:** Elaborar mandalas con semillas para explorar patrones y fracciones.
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ---
#
# ### 8. **Aprendizaje Cooperativo con Roles Comunitarios**
# **Descripción:** Trabajo en grupos con roles inspirados en oficios locales (ej. "agricultores" que miden parcelas, "comerciantes" que suman precios).
# **Justificación:** Fomenta la comunicación matemática y la interdependencia positiva.
# **Aplicación:** Simular un mercado caucasiano para practicar sumas y restas.
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ---
#
# ### 9. **Enfoque Reggio Emilia Adaptado al Entorno**
# **Descripción:** Espacios de exploración autónoma con elementos naturales (hojas, ramas) para clasificar, seriar y contar.
# **Justificación:** Empodera a los niños como constructores activos de su conocimiento, en línea con Freire.
# **Ejemplo:** "Rincones matemáticos" con materiales recogidos en salidas al entorno rural.
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ---
#
# ### 10. **Integración de TIC con Recursos Accesibles**
# **Descripción:** Usar apps gratuitas (ej. "Geogebra" o "Math Kids") y herramientas audiovisuales para reforzar conceptos.
# **Justificación:** Desarrolla competencias digitales sin dejar de lado la reflexión crítica.
# **Contexto:** Crear videos con celulares donde los niños expliquen cómo miden objetos de su casa.
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ---
#
#
#
# ### 11. El enfoque pedagógico correspondiente a Raymond Duval en su psicología cognitiva para el aprendizaje de la matemática es **la teoría de los registros de representación semiótica**.
#
# Este enfoque es **altamente aplicable** para el desarrollo del pensamiento matemático en la infancia, específicamente en los grados preescolar, primero, segundo y tercero, porque:
#
# 1. **Favorece la comprensión de conceptos matemáticos** a través de la transformación y coordinación entre diferentes representaciones (icónica, gráfica, verbal, simbólica, etc.).
# 2. **Permite adaptar la enseñanza a las capacidades cognitivas de los niños**, utilizando representaciones más accesibles en las primeras etapas (como materiales concretos, dibujos y lenguaje oral) antes de introducir notaciones simbólicas formales.
# 3. **Facilita el razonamiento matemático** al hacer que los niños se familiaricen con la necesidad de cambiar entre representaciones, como interpretar una cantidad en objetos físicos, en un dibujo, en un número escrito y en una expresión verbal.
# 4. **Refuerza el desarrollo del pensamiento abstracto** al permitir que los niños internalicen estructuras matemáticas mediante la interacción con distintos registros.
#
# En resumen, la teoría de Duval es una base sólida para diseñar estrategias didácticas que promuevan el desarrollo del pensamiento matemático en la infancia.
#
# #### Ejemplo de utilización de este enfoque:
#
#
#
# ### Articulación con los Ejes del Curso:
# - **Formativo:** Enfoques como ABJ y aprendizaje cooperativo fortalecen la vocación docente mediante la creación de ambientes lúdicos.
# - **Disciplinar:** La modelación y resolución de problemas abordan componentes numérico-variacionales y aleatorios.
# - **Investigativo:** Los proyectos de aula y sistematización con materiales locales promueven la observación estructurada.
#
# ---

# %% [markdown]
# # Formato de Caracterización
#
#
# Aquí tienes el **formato de caracterización** para los practicantes de Práctica Pedagógica V, alineado con la rúbrica proporcionada y enfocado en el desarrollo del pensamiento matemático en preescolar y primeros grados de primaria. Incluye indicaciones para elegir los tres enfoques pedagógicos más pertinentes:
#
# ---
#
# # **FORMATO DE CARACTERIZACIÓN**
# **Práctica Pedagógica V – Universidad de Antioquia**
# **Liceo Caucasia (Antioquia)**
# **Fecha de entrega: 18 de abril de 2025**
#
# ---
#
# ### **1. Datos generales**
# | **Campo**               | **Descripción** |
# |--------------------------|----------------|
# | Nombre del practicante   |                |
# | Grado(s) asignado(s)     | (Preescolar, 1°, 2°, 3°) |
# | Fechas de visita         | (2 jueves: especificar fechas) |
# | Total horas realizadas   | 8 horas |
#
# ---
#
# ### **2. Análisis del contexto institucional** *(Criterio 1)*
# - **PEI y plan de estudios**:
#   - Principios pedagógicos del Liceo Caucasia relacionados con matemáticas.
#   - Recursos disponibles (materiales, infraestructura, TIC).
#   - **Evidencia**: Fotografías o extractos de documentos institucionales.
#
# - **Enfoques pedagógicos institucionales**:
#   - ¿Qué metodologías usa la escuela para enseñar matemáticas? (Ej: aprendizaje por proyectos, clases magistrales).
#
# ---
#
# ### **3. Diagnóstico de prácticas docentes** *(Criterio 2)*
# - **Observación de clases**:
#   - Estrategias usadas por los docentes (ej: uso de material concreto, resolución de problemas).
#   - Dificultades identificadas (ej: falta de recursos, resistencia al cambio).
#   - **Evidencia**: Fragmentos de diario pedagógico o transcripción de entrevistas a docentes.
#
# ---
#
# ### **4. Evaluación de estudiantes** *(Criterio 3)*
# - **Habilidades matemáticas**:
#   - Nivel de dominio en conteo, operaciones básicas, geometría (según grado).
#   - Instrumentos: Encuestas a niños, observación de actividades lúdicas, análisis de trabajos.
#
# - **Actitudes**:
#   - Motivación, miedo a las matemáticas, participación en clase.
#   - **Evidencia**: Tabla resumen con datos cuantitativos/cualitativos.
#
# ---
#
# ### **5. Identificación de necesidades** *(Criterio 4)*
# | **Necesidad**            | **Posible solución** | **Referente curricular (DBA/Estándares)** |
# |--------------------------|----------------------|-------------------------------------------|
# | Ej: Bajo uso de material concreto | Taller con semillas para operaciones básicas | DBA 1°: "Usar objetos para representar cantidades" |
#
# ---
#
# ### **6. Propuesta de tres enfoques pedagógicos**
# *(Seleccionar 3 de los 11 enfoques listados, justificando su elección con base en el diagnóstico)*
#
# | **Enfoque**              | **Justificación** | **Ejemplo de actividad** |
# |--------------------------|-------------------|--------------------------|
# | Ej: **Aprendizaje Basado en Juegos (ABJ)** | Los niños muestran alta motivación con lo lúdico, pero falta estructura pedagógica. | "Lotería de sumas" con semillas de plátano. |
# | **Enfoque sociocultural** | El contexto rural permite vincular matemáticas a cultivos locales. | Calcular rendimiento de cosechas en huerta escolar. |
# | **Registros de representación semiótica (Duval)** | Los niños confunden números con su representación gráfica. | Transformar cantidades de piedras a dibujos y símbolos. |
#
# ---
#
# ### **7. Reflexión crítica**
# - **Hallazgos clave**: Brechas entre teoría y práctica, oportunidades de innovación.
# - **Conexión con la ruralidad**: Ej: Adaptar materiales por falta de recursos tecnológicos.
#
# ---
#
# ### **8. Anexos**
# - Fotografías de observaciones.
# - Transcripciones de entrevistas.
# - Ejemplos de trabajos estudiantiles.
#
# ---
#
# ### **Recomendaciones para los practicantes**:
# 1. **Priorizar enfoques contextualizados**: Ej: Si hay baja motivación, usar ABJ; si hay dificultades en abstracción, aplicar Duval.
# 2. **Triangulación de datos**: Cruzar observaciones, entrevistas y análisis documental.
# 3. **Normas APA**: Citar Lineamientos Curriculares del MEN, estándares básicos y teorías como Piaget o Vygotsky.
#
# **Nota**: Este formato debe complementarse con el **video explicativo** (4 de abril) donde presenten los 3 enfoques elegidos, mostrando ejemplos concretos de actividades.
#
# ---
#
# ### **Ejemplo de selección de enfoques para Caucasia**:
# 1. **Aprendizaje Basado en Juegos** (para motivación en preescolar).
# 2. **Modelación matemática con contextos rurales** (para vincular matemáticas y agricultura en 2°-3°).
# 3. **Registros de representación semiótica** (para superar confusiones en notación numérica en 1°).

# %%
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH

def crear_doc_caracterizacion():
    # Crear un nuevo documento
    doc = Document()
    
    # Configuración básica de estilos
    style = doc.styles['Normal']
    font = style.font
    font.name = 'Arial'
    font.size = Pt(11)
    
    # Título principal
    titulo = doc.add_heading('FORMATO DE CARACTERIZACIÓN', level=1)
    titulo.alignment = WD_ALIGN_PARAGRAPH.CENTER
    
    # Subtítulo
    subtitulo = doc.add_heading('Práctica Pedagógica V – Universidad de Antioquia\nLiceo Caucasia (Antioquia)\nFecha de entrega: 18 de abril de 2025', level=2)
    subtitulo.alignment = WD_ALIGN_PARAGRAPH.CENTER
    
    # Sección 1: Datos generales
    doc.add_heading('1. Datos generales', level=2)
    tabla_datos = doc.add_table(rows=5, cols=2)  # Aumenté a 5 filas (1 header + 4 campos)
    tabla_datos.style = 'Table Grid'
    
    # Encabezados de la tabla
    celdas_encabezado = tabla_datos.rows[0].cells
    celdas_encabezado[0].text = 'Campo'
    celdas_encabezado[1].text = 'Descripción'
    
    # Datos de la tabla
    campos = [
        'Nombre del practicante',
        'Grado(s) asignado(s)',
        'Fechas de visita',
        'Total horas realizadas'
    ]
    
    for i in range(1, 5):  # Usamos range(1, 5) porque las filas van de 0 a 4
        row = tabla_datos.rows[i].cells
        row[0].text = campos[i-1]
        row[1].text = ''  # Espacio para que el usuario complete
    
    # Resto del documento (sin cambios)...
    # Sección 2: Análisis del contexto institucional
    doc.add_heading('2. Análisis del contexto institucional', level=2)
    doc.add_paragraph('• PEI y plan de estudios:', style='List Bullet')
    doc.add_paragraph('   - Principios pedagógicos del Liceo Caucasia relacionados con matemáticas.', style='List Bullet')
    doc.add_paragraph('   - Recursos disponibles (materiales, infraestructura, TIC).', style='List Bullet')
    doc.add_paragraph('   - Evidencia: Fotografías o extractos de documentos institucionales.', style='List Bullet')
    doc.add_paragraph('• Enfoques pedagógicos institucionales:', style='List Bullet')
    doc.add_paragraph('   - ¿Qué metodologías usa la escuela para enseñar matemáticas?', style='List Bullet')
    
    # Sección 3: Diagnóstico de prácticas docentes
    doc.add_heading('3. Diagnóstico de prácticas docentes', level=2)
    doc.add_paragraph('• Observación de clases:', style='List Bullet')
    doc.add_paragraph('   - Estrategias usadas por los docentes.', style='List Bullet')
    doc.add_paragraph('   - Dificultades identificadas.', style='List Bullet')
    doc.add_paragraph('   - Evidencia: Fragmentos de diario pedagógico o transcripción de entrevistas.', style='List Bullet')
    
    # Sección 4: Evaluación de estudiantes
    doc.add_heading('4. Evaluación de estudiantes', level=2)
    doc.add_paragraph('• Habilidades matemáticas:', style='List Bullet')
    doc.add_paragraph('   - Nivel de dominio en conteo, operaciones básicas, geometría.', style='List Bullet')
    doc.add_paragraph('   - Instrumentos: Encuestas a niños, observación de actividades.', style='List Bullet')
    doc.add_paragraph('• Actitudes:', style='List Bullet')
    doc.add_paragraph('   - Motivación, miedo a las matemáticas, participación.', style='List Bullet')
    
    # Sección 5: Identificación de necesidades
    doc.add_heading('5. Identificación de necesidades', level=2)
    tabla_necesidades = doc.add_table(rows=2, cols=3)  # 1 header + 1 fila de ejemplo
    tabla_necesidades.style = 'Table Grid'
    headers = tabla_necesidades.rows[0].cells
    headers[0].text = 'Necesidad'
    headers[1].text = 'Posible solución'
    headers[2].text = 'Referente curricular'
    # Añadir fila de ejemplo
    row = tabla_necesidades.rows[1].cells
    row[0].text = 'Ej: Bajo uso de material concreto'
    row[1].text = 'Taller con semillas para operaciones básicas'
    row[2].text = 'DBA 1°: "Usar objetos para representar cantidades"'
    
    # Sección 6: Enfoques pedagógicos
    doc.add_heading('6. Propuesta de tres enfoques pedagógicos', level=2)
    doc.add_paragraph('Seleccionar 3 de los 11 enfoques listados, justificando su elección:')
    tabla_enfoques = doc.add_table(rows=2, cols=3)  # 1 header + 1 fila de ejemplo
    tabla_enfoques.style = 'Table Grid'
    headers = tabla_enfoques.rows[0].cells
    headers[0].text = 'Enfoque'
    headers[1].text = 'Justificación'
    headers[2].text = 'Ejemplo de actividad'
    # Añadir fila de ejemplo
    row = tabla_enfoques.rows[1].cells
    row[0].text = 'Aprendizaje Basado en Juegos (ABJ)'
    row[1].text = 'Los niños muestran alta motivación con lo lúdico.'
    row[2].text = '"Lotería de sumas" con semillas de plátano.'
    
    # Sección 7: Reflexión crítica
    doc.add_heading('7. Reflexión crítica', level=2)
    doc.add_paragraph('• Hallazgos clave: Brechas entre teoría y práctica, oportunidades de innovación.', style='List Bullet')
    doc.add_paragraph('• Conexión con la ruralidad: Ej: Adaptar materiales por falta de recursos.', style='List Bullet')
    
    # Sección 8: Anexos
    doc.add_heading('8. Anexos', level=2)
    doc.add_paragraph('• Fotografías de observaciones.', style='List Bullet')
    doc.add_paragraph('• Transcripciones de entrevistas.', style='List Bullet')
    doc.add_paragraph('• Ejemplos de trabajos estudiantiles.', style='List Bullet')
    
    # Guardar el documento
    doc.save('Caracterizacion_Practica_Pedagogica_V.docx')
    print("Documento generado con éxito: 'Caracterizacion_Practica_Pedagogica_V.docx'")

# Ejecutar la función
crear_doc_caracterizacion()
# Out:
# Documento generado con éxito: 'Caracterizacion_Practica_Pedagogica_V.docx'

# %% [markdown]
# 1. Datos generales del niño.
# 2. Contexto familiar y socioeconómico.
# 3. Intereses y necesidades del niño.
# 4. Análisis y reflexión.
# 5. Propuesta de intervención.

# %% [markdown]
# ## 5. Mapa Conceptual (Graphviz en Python)
# **Ubicación de renderizado:** `C:\Users\marco\Downloads`

# %%
from graphviz import Digraph
import os

dot = Digraph(comment='Mapa Conceptual del Taller', format='png')
dot.node('A', 'Caracterización', shape='box', style='filled', fillcolor='lightblue')
dot.node('B', 'Contexto', shape='ellipse', style='filled', fillcolor='lightyellow')
dot.node('C', 'Metodologías', shape='diamond', style='filled', fillcolor='lightgreen')
dot.edge('A', 'B')
dot.edge('A', 'C')
dot.render(view=True, directory='C:\\Users\\marco\\Downloads')
# Out:
# 'C:\\Users\\marco\\Downloads\\Digraph.gv.png'

# %% [markdown]
# ## 6. Elementos Históricos y Epistemológicos
# - Historia de la educación infantil y la importancia de la contextualización.
# - Ilustraciones sobre cómo los niños aprenden en diferentes contextos.
#
# ## 7. Actividades de Aprendizaje
# - Juego de roles en entrevistas.
# - Representación artística del contexto infantil.
# - Actividad lúdica de análisis de datos en Python.
#
# ## 8. Canciones y Poemas
# - **"Aprendamos con el entorno"** (canción infantil sobre la importancia del contexto).
#
# ## 9. Tareas y Actividades de Fijación
# - Aplicación de entrevistas y análisis de datos.
# - Implementación de una estrategia didáctica basada en el contexto.
#
# ## 10. Evaluación
# **Ejemplo de quiz:**
# 1. ¿Qué elementos componen la caracterización del contexto infantil?
# 2. ¿Cómo puede influir el contexto en el aprendizaje de los niños?
# 3. ¿Qué herramientas de Python se pueden usar para analizar datos en educación infantil?
#
# ## 11. Retroalimentación
# - Discusión en grupos sobre los aprendizajes obtenidos.
# - Reflexión sobre la aplicabilidad en la práctica docente.
#
# ## 12. Vocabulario y Frases en Inglés
# - "Educational context" (Contexto educativo)
# - "Child-centered teaching" (Enseñanza centrada en el niño)
#
# ## 13. Apéndice sobre Habilidades de Trabajo en Equipo e Inteligencia Emocional
# - **Trabajo en equipo:** Empatía, comunicación efectiva, respeto.
# - **Inteligencia emocional en evaluaciones:** Manejo del estrés, honestidad académica.
#
# ## 14. Referencias en Didáctica de la Matemática
# **Ejemplo en APA:**
# - Duval, R. (2006). Representaciones y cambios de representación para la adquisición de conceptos matemáticos. *Educational Studies in Mathematics, 63*(2), 103-131.
# - Wing, J. M. (2006). Computational thinking. *Communications of the ACM, 49*(3), 33-35.
#
# _(Se incluirán 10 referentes adicionales)._
#
# ---
# Este diseño de taller promueve el aprendizaje experiencial en Jupyter Notebooks mediante la aplicación de Python para la visualización y análisis de datos en la caracterización del contexto infantil.

# %% [markdown]
# # ARTÍCULO 1. Definir el calendario académico para los diferentes programas de pregrado de los campus
# regionalizados, correspondiente al primer periodo académico del año 2025, así:
# * Oferta 28 de enero de 2025
# * Matrícula 30 de enero de 2025
# * Ajustes 03 al 10 de febrero de 2025
# * Inicio de clases 10 de febrero de 2025
# * Límite evaluación del 40% 06 de abril de 2025
# * Terminación de clases 08 de junio de 2025
# * Exámenes finales 09 al 15 de junio de 2025
# * Habilitación y validación 16 al 22 de junio de 2025
# * Terminación oficial 23 de junio de 2025

# %% [markdown]
# # Cursos que orienta el profesor Marco Julio Cañas Campillo en 2025
#
# 1. Práctica Pedagógica V para Licenciatura en Educación Infantil
# 2. Fundamentos de Lógica para Licenciatura en Matemáticas
# 3. Análisis Numérico para Licenciatura en Matemáticas.
# 4. Cálculo Vectorial para Ingeniería Agropecuaria

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12: Cálculo Vectorial
# * Martes 8-12 M: Fundamentos de Aritmética.
# * Miércoles 8 a 12 M: Fundamentos de la Lógica
# * Jueves 2 a 6 PM: Desarrollo del pensamiento matemático en la infancia.
# * Viernes 8 - 12 M: Desarrollo del pensamiento matemático en la infancia.
# * Sábados 8-12 Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.

# %% [markdown]
# # Horarios de monitoría y asesoría
#
# Coordinador de los cursos de la Facultad de Educación para regiones:
#
# Andrés Vélez: regioneducacion.fedu@udea.edu.co
# Coordinador Regiones
# Facultad de Educación
# Universidad de Antioquia

# %% [markdown]
# ## Monitor Manuel San Juan Serrano
#
# Contactar escribiendo al correo: manuel.serrano1@udea.edu.co

# %% [markdown]
# Martes y jueves de 8 - 12
# Miércoles 10 - 12 y de 2 a 4 PM
# Sábado: 8 - 12

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Página de la Licenciatura en Educación Infantil](https://www.udea.edu.co/wps/portal/udea/web/inicio/unidades-academicas/educacion/oferta-pregrado/licenciatura-educacion-infantil/!ut/p/z0/04_Sj9CPykssy0xPLMnMz0vMAfIjo8zi_QJNXQ2NnA18DII9zQwCPU1MPcOcwswtnQ30C7IdFQEJdH3t/?1dmy&urile=wcm%3Apath%3A/PortalUdeA/asPortalUdeA/asHomeUdeA/Unidades+Acad%21c3%21a9micas/Educaci%21c3%21b3n/Oferta+de+Pregrado/Licenciatura+en+Pedagog%21c3%21ada+Infantil/Contenido/asMenuLateral/perfil)
#
#
# * [Lineamientos curriculares del MEN](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.mineducacion.gov.co/1780/articles-339975_matematicas.pdf)
#
# * [Estándares Básicos de Competencias](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.mineducacion.gov.co/1621/articles-340021_recurso_1.pdf)
#
# * [Derechos Básicos de Aprendizaje DBA](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.colombiaaprende.edu.co/sites/default/files/files_public/2022-06/DBA_Matematicas-min.pdf)
#
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html
#
#
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
# * [La inteligencia artificial DeepSeek](https://www.deepseek.com/)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Apéndice sobre calendarios y coordinaciones
#
# A continuación le envío el horario de la asignatura Cálculo Vectorial
#
# Días:
# Lunes - Hora: 7:00 a 12:00M
# Fechas:
# Febrero: 10-17-24
#  Marzo: 3-10-17-31
# Abril:7-21-28
# Mayo:5-12-19
#
# Agradezco su apoyo, y si presenta alguna dificultad puede contactarme.
#
# Cordialmente,
# Juan Felipe Rivera Hernández
# Contacto: 3106314300

# %% [markdown]
# # Clase de análisis numérico los Martes de 8 a 12 del medio día.
