# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/1_evaluacion_oral_tarea_quiz_parcial.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# # Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas y administración de empresas
#
# [Hábitos atómicos](https://github.com/marco-canas/habitos_atomicos/blob/main/13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos/1_13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos.ipynb)

# %% [markdown]
# # Título de la clase: Realización evaluación oral, de Tareas en cuadernos Jupyter, Quiz o Parcial de selección múltiple o de preguntas cerradas.

# %% [markdown]
# # Prompt para pedir el diseño de evaluación de acuerdo a la metodología de "Enseñanza basada en proyectos"

# %% [markdown]
# # Estructura general para todas las clases
#
# Dame, por favor, un diseño de Taller, con el enfoque: Aula Invertida, STEAMS y de Aprendizaje Basado en Problemas y Proyectos (ABPP) sobre: "Taller para formación de Maestros sobre: Cómo realizar la caracterización del contexto y de los niños en la Práctica Pedagógica V para Educación Infantil" siguiendo la estructura:
#
# 1. Metodología del Taller: **5. Método "Design Thinking"**
# **Objetivo:** Diseñar prácticas pedagógicas centradas en el niño.
#     **Fases:**
#     1. **Empatizar (parejas):** Entrevistas simuladas para identificar necesidades de los niños.
#     2. **Definir (grupos):** Sintetizar hallazgos (ej: *"Los niños aprenden mejor con materiales concretos de su entorno"*).
#     3. **Prototipar (grupos):** Crear una actividad matemática usando solo recursos locales (ej: semillas, piedras).
#     4. **Testear (parejas):** Un maestro implementa la actividad, el otro observa y registra.
#
#     **Producto:** Kit de actividades matemáticas contextualizadas.
#
# 2. Título del taller.
#
# 3. Objetivos de aprendizaje que incluyan los indicadores del logro de estos
#    objetivos.
#
# 4. Contenido de la taller. Incluye el formato para entregar el informe de
#    Caracterización en la práctica V en el Liceo Caucasia
#
# 5. Un mapa conceptual que resuma la clase elaborado en Graphviz de Python con nodos y edges de diferentes formas, colores y rellenos y renderizado en la siguiente ubicación: `"C:\Users\marco\Downloads"`. No olvides el parámetro `view = True` ppara el método `render()` de `Graphviz`.
#
# 6. Elementos históricos y epistemológicos relevantes para la clase y enunciados con ilustraciones para niños de 8 años.
#
# 7. Actividades de aprendizaje que incluyan componente lúdico, cotidiano y artístico.
#
# 8. Incluye una canción o un poema que ayude a interiorizar y fijar los conceptos asociados a esta clase.
#
# 9.  Tarea o actividades de ejercitación y fijación.
#
# 10. Evaluación incluyendo diez proyectos, un ejemplo de quiz (de tres preguntas) y un ejemplo de parcial (De cinco preguntas).
#
# 11. Diseño de actividad de retroalimentación.
#
# 12. Dame un vocabulario y frases del idioma inglés asociadas a esta clase.
#
# 13.   Incluye apéndice para la clase sobre desarrollo de habilidades para trabajar en equipo y de asertividad y empatía para relacionarnos. También elementos de la inteligencia emocional para presentar pruebas sin temor y sin realizar fraude en ellas. Elementos de la inteligencia Emocional para comportarnos en clase de manera no reactiva y muy asertiva, con trato amable y constructiva.
#
# 14. Incluye 10 referentes en didáctica de la matemática que estén de acuerdo a la propuesta didáctica de este taller. Adiciona a estos referentes a Raymond Duval (Representaciones y cambios de representación para la adquisición de conceptos matemáticos) y a Jeannette Wing (Desarrollo del pensamiento computacional). Déjame todos estos referentes ordenados de acuerdo a las normas APA. Déjame todos estos referentes ordenados de acuerdo a las normas APA. Incluye las citaciones a estos referentes a medida que vallas diseñando la clase.
#
# Pero  que este diseño sea para que el estudiante pueda aprender experimentando en cuadernos Jupyter con funciones de usuario y animaciones y visualizaciones en python. En particular utiliza NumPy, Pandas, Sympy, Matplotlib.pyplot, plotly, Seaborn, matplotlib.animation, ipywidgets. Cada vez que itilice `matplotlib.animacion` no olvides incluir el uso de IPython. display para la rederización de estas animaciones a través de Jupyter Notebook. No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dolar $ para que VS Code si me renderice estas expresiones del lenguaje latex.
#
# En particular utiliza NumPy, Pandas, Sympy, Matplotlib.pyplot, plotly, Seaborn, matplotlib.animation, ipywidgets.
#
# Cada vez que itilice `matplotlib.animacion` no olvides incluir el uso de `IPython. display` para la renderización de estas animaciones a través de Jupyter Notebook. No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dólar $ para que VS Code si me renderice estas expresiones del lenguaje Latex.

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# # FODA del grupo y del profesor
#
# * F: Fortalezas
# * O: Oportunidades
# * D: Dificultades
# * A: Amenazas.

# %% [markdown]
# ## ¿Cómo se sintió en este espacio de enseñanza y aprendizaje?
#
# !Dios te bendiga¡

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Página de la Licenciatura en Educación Infantil](https://www.udea.edu.co/wps/portal/udea/web/inicio/unidades-academicas/educacion/oferta-pregrado/licenciatura-educacion-infantil/!ut/p/z0/04_Sj9CPykssy0xPLMnMz0vMAfIjo8zi_QJNXQ2NnA18DII9zQwCPU1MPcOcwswtnQ30C7IdFQEJdH3t/?1dmy&urile=wcm%3Apath%3A/PortalUdeA/asPortalUdeA/asHomeUdeA/Unidades+Acad%21c3%21a9micas/Educaci%21c3%21b3n/Oferta+de+Pregrado/Licenciatura+en+Pedagog%21c3%21ada+Infantil/Contenido/asMenuLateral/perfil)
#
# * [Lineamientos curriculares del MEN](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.mineducacion.gov.co/1780/articles-339975_matematicas.pdf)
#
# * [Estándares Básicos de Competencias](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.mineducacion.gov.co/1621/articles-340021_recurso_1.pdf)
#
# * [Derechos Básicos de Aprendizaje DBA](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.colombiaaprende.edu.co/sites/default/files/files_public/2022-06/DBA_Matematicas-min.pdf)
#
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
# * [La inteligencia artificial DeepSeek](https://www.deepseek.com/)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)
#
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.
