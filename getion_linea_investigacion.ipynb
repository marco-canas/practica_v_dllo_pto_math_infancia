# %% [markdown]
# # Prompt para el diseño de la base de datos
#
# Dame, una función de usuario de python que me permita ingresar para cada grupo de prácticantes:  2 necesidades educativas que observen en los niños, en cuanto al desarrollo del pensamiento matemático en la infancia; luego ingresar los referentes teóricos curriculares que sustenten estas necesidad educativas; luego ingresar las posibles soluciones a la luz de referentes en didáctica de la matemática; luego ingresar los enfoques pedagógicos que sean coeherentes con la solución; ingresar la redacción de la hipótesis de investigación; luego ingresar 7 objetivos de aprendizaje que busquen resolver las necesidades educativas planteadas.  Por tanto, los parámetros para esta función de python son: El ID del grupo de practicantes, necesidades encontradas en la caracterización,  referentes_teoricos_curriculares, posibles soluciones a tales necesidades educativas, enfoques_pedagogicos, hipótesis_investigativa, siete_objetivos_aprendizaje. Que esta función, guarde esta información en una estructura de DataFrame

# %%
def registrar_informacion_practicantes(id_grupo, necesidades, referentes_teoricos_curriculares, soluciones, enfoques_pedagogicos, hipotesis_investigativa, objetivos_aprendizaje):
    """
    Registra la información de un grupo de practicantes en un DataFrame.

    Parámetros:
    - id_grupo: ID del grupo de practicantes.
    - necesidades: Lista de 2 necesidades educativas observadas.
    - referentes_teoricos_curriculares: Referentes teóricos curriculares que sustentan las necesidades.
    - soluciones: Posibles soluciones basadas en referentes de didáctica de la matemática.
    - enfoques_pedagogicos: Enfoques pedagógicos coherentes con las soluciones.
    - hipotesis_investigativa: Redacción de la hipótesis de investigación.
    - objetivos_aprendizaje: Lista de 7 objetivos de aprendizaje.

    Retorna:
    - Un DataFrame con la información registrada.
    """
    # Crear un diccionario con los datos
    data = {
        'ID_Grupo': [id_grupo],
        'Necesidades': [necesidades],
        'Referentes_Teoricos_Curriculares': [referentes_teoricos_curriculares],
        'Soluciones': [soluciones],
        'Enfoques_Pedagogicos': [enfoques_pedagogicos],
        'Hipotesis_Investigativa': [hipotesis_investigativa],
        'Objetivos_Aprendizaje': [objetivos_aprendizaje]
    }
    
    # Crear un DataFrame con los datos
    df_practicantes = pd.DataFrame(data)
    return df_practicantes

# %%
# Ejemplo de uso
import pandas as pd 
df_practicantes = registrar_informacion_practicantes(
    id_grupo=2,
    necesidades=[],
    referentes_teoricos_curriculares="",
    soluciones="",
    enfoques_pedagogicos=["Aprendizaje Basado en el Uso de Material Concreto ", \
        "Aprendizaje Basado en Juegos (ABJ)", \
            "Resolución de Problemas Contextualizados", \
                "Aprendizaje Significativo", \
                    "Aprendizaje Colaborativo"],
    hipotesis_investigativa="",
    objetivos_aprendizaje=[
        ]
)

print(df_practicantes)
# Out:
#    ID_Grupo Necesidades Referentes_Teoricos_Curriculares Soluciones  \
# 0         2          []
#
#                                 Enfoques_Pedagogicos Hipotesis_Investigativa  \
# 0  [Aprendizaje Basado en el Uso de Material Conc...
#
#   Objetivos_Aprendizaje
# 0                    []

# %%
df_practicantes.to_csv("practicantes.csv", index=False)

# %%
df_practicantes
# Out:
#    ID_Grupo Necesidades Referentes_Teoricos_Curriculares Soluciones  \
# 0         2          []
#
#                                 Enfoques_Pedagogicos Hipotesis_Investigativa  \
# 0  [Aprendizaje Basado en el Uso de Material Conc...
#
#   Objetivos_Aprendizaje
# 0                    []

# %%
df_practicantes.Enfoques_Pedagogicos[0]
# Out:
# ['Aprendizaje Basado en el Uso de Material Concreto ',
#  'Aprendizaje Basado en Juegos (ABJ)',
#  'Resolución de Problemas Contextualizados',
#  'Aprendizaje Significativo',
#  'Aprendizaje Colaborativo']
