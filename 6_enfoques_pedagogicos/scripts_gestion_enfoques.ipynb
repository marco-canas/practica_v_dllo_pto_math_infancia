# %% [markdown]
# # Gestión de los enfoques pedagógicos para el desarrollo del pensamiento matemático en la infancia en Caucasia - Antioquia

# %% [markdown]
# Dame un script de python para crear 10 carpetas en la ubicación "C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos" y que se nombren con el siguiente formato: "Enfoque_1", "Enfoque_2", ...., "Enfoque_10"

# %% [markdown]
# Aquí tienes un script de Python que creará las 10 carpetas con el formato solicitado:
#
# ```python

# %%
import os

# Definir la ruta base
base_path = r"C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos"

# Crear las 10 carpetas
for i in range(1, 11):
    folder_name = f"Enfoque_{i}"
    folder_path = os.path.join(base_path, folder_name)
    
    # Crear la carpeta si no existe
    os.makedirs(folder_path, exist_ok=True)
    print(f"Carpeta creada: {folder_path}")

print("\n¡Todas las carpetas han sido creadas exitosamente!")
# Out:
# Carpeta creada: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\Enfoque_1
# Carpeta creada: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\Enfoque_2
# Carpeta creada: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\Enfoque_3
# Carpeta creada: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\Enfoque_4
# Carpeta creada: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\Enfoque_5
# Carpeta creada: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\Enfoque_6
# Carpeta creada: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\Enfoque_7
# ...

# %% [markdown]
# Explicación del script:
#
# 1. `import os`: Importa el módulo necesario para trabajar con el sistema operativo
#
# 2. `base_path`: La ruta donde se crearán las carpetas, usando un string raw (`r""`) para manejar correctamente las barras invertidas en Windows
#
# 3. El bucle `for` itera de 1 a 10 (el `range(1, 11)` genera números del 1 al 10)
#
# 4. `folder_name`: Genera el nombre de cada carpeta usando f-strings
#
# 5. `folder_path`: Combina la ruta base con el nombre de cada carpeta
#
# 6. `os.makedirs()`: Crea el directorio con dos parámetros importantes:
#    - `folder_path`: Ruta completa a crear
#    - `exist_ok=True`: Evita errores si la carpeta ya existe
#
# 7. Los mensajes `print()` muestran el progreso y confirmación final
#
# Ejecuta este script y se crearán las carpetas con la estructura solicitada. Si alguna carpeta ya existe, el script simplemente la ignorará gracias al parámetro `exist_ok=True`.

# %% [markdown]
# # Scripts para la gestión de los archivos .md para la presentación de cada uno de los 11 enfoques pedagógicos para práctica V

# %% [markdown]
# 1. **Aprendizaje Basado en Retos (ABR)**
#    - Divide la clase en grupos y asigna a cada grupo un enfoque pedagógico.
#    - Cada equipo debe diseñar y demostrar una actividad didáctica basada en su enfoque.
#    - Los demás compañeros hacen preguntas y reflexionan sobre su aplicabilidad.
#
# 2. **Taller de Experiencias Sensoriales**
#    - Prepara estaciones con materiales concretos (semillas, bloques, hojas) que representen distintos enfoques.
#    - Los estudiantes rotan entre estaciones y registran cómo cada enfoque favorece el pensamiento matemático.
#
# 3. **Role-Playing Docente**
#    - Cada estudiante asume el papel de un maestro y expone un enfoque pedagógico a sus "alumnos" (sus compañeros).
#    - Debe incluir una mini actividad didáctica.
#    - La clase brinda retroalimentación sobre claridad y aplicabilidad.
#
# 4. **Infografías y Visual Thinking**
#    - Los estudiantes crean infografías digitales o murales visuales explicando un enfoque pedagógico.
#    - Se exponen en el aula o en redes sociales académicas (ej. Padlet, Instagram académico).
#
# 5. **Círculo Socrático con Preguntas Críticas**
#    - Se plantean preguntas como:
#      - ¿Qué enfoque es más viable en un aula rural sin tecnología?
#      - ¿Cómo se combinan varios enfoques en una misma actividad?
#    - Los estudiantes debaten en círculo, justificando con ejemplos.
#
# 6. **Escape Room Pedagógico**
#    - Se diseñan acertijos y desafíos donde cada pista lleva a descubrir un enfoque pedagógico.
#    - Los estudiantes deben relacionar teorías con prácticas didácticas para avanzar.
#
# 7. **Creación de Recursos Didácticos**
#    - Cada grupo diseña un recurso didáctico (video, cuento, canción) aplicando un enfoque.
#    - Se presentan en clase y se suben a una plataforma colaborativa.
#
# ---

# %% [markdown]
# Aquí tienes el código modificado para que la información de los enfoques pedagógicos esté organizada en un **diccionario** y se use **pandas** para crear el archivo `.csv`:

# %%
import pandas as pd

# Diccionario con los enfoques pedagógicos
enfoques = {
    "Enfoque": [
        "Aprendizaje Basado en Juegos (ABJ)",
        "Enfoque Sociocultural con Pertinencia Local",
        "Resolución de Problemas Cotidianos",
        "Manipulación de Material Concreto",
        "Proyectos de Aula con Enfoque Investigativo",
        "Modelación Matemática con Contextos Rurales",
        "Pensamiento Visible a través del Arte",
        "Aprendizaje Cooperativo con Roles Comunitarios",
        "Enfoque Reggio Emilia Adaptado",
        "Integración de TIC con Recursos Accesibles",
        "Teoría de los Registros de Representación Semiótica (Raymond Duval)"
    ],
    "Descripcion": [
        "Integrar juegos estructurados para desarrollar conceptos matemáticos.",
        "Vincular las matemáticas a prácticas culturales y económicas de la región.",
        "Plantear problemas reales del entorno para el desarrollo de habilidades matemáticas.",
        "Uso de objetos tangibles para enseñar operaciones básicas y geometría.",
        "Diseñar secuencias didácticas basadas en preguntas de los niños.",
        "Representar matemáticamente situaciones del campo y la naturaleza.",
        "Uso de dibujos, música y danza para expresar conceptos matemáticos.",
        "Trabajo en grupos con roles inspirados en la vida cotidiana.",
        "Espacios de exploración autónoma con elementos naturales.",
        "Uso de apps y herramientas digitales para reforzar conceptos matemáticos.",
        "Transformar y coordinar diferentes representaciones matemáticas."
    ],
    "Justificación": [
        "Promueve el aprendizaje lúdico y el desarrollo sensoriomotor.",
        "Alinea con los lineamientos curriculares del MEN.",
        "Desarrolla competencias para 'saber hacer' en contextos reales.",
        "Favorece la etapa sensoriomotora y operacional concreta en niños.",
        "Fortalece el eje investigativo y la sistematización de datos.",
        "Alinea con los Derechos Básicos de Aprendizaje (DBA).",
        "Fomenta la expresión creativa y la integración del arte con la matemática.",
        "Fomenta la comunicación matemática y la interdependencia positiva.",
        "Empodera a los niños como constructores activos del conocimiento.",
        "Desarrolla competencias digitales sin perder la reflexión crítica.",
        "Facilita la comprensión abstracta mediante múltiples registros."
    ]
}

# Convertir el diccionario en un DataFrame
df = pd.DataFrame(enfoques)

# Guardar el DataFrame en un archivo CSV
df.to_csv("enfoques_pedagogicos.csv", index=False, encoding="utf-8")

print("Archivo CSV generado con éxito.")
# Out:
# Archivo CSV generado con éxito.

# %% [markdown]
# ✅ **¿Qué mejora este código?**
# 1. **Estructura más clara**: La información está organizada en un diccionario con claves significativas.
# 2. **Uso de pandas**: Convierte el diccionario en un DataFrame de manera eficiente.
# 3. **Código más limpio**: Evita escribir manualmente filas en el CSV.
# 4. **Mejor compatibilidad**: Permite futuras modificaciones o análisis en Python con facilidad.
#
# 🚀 ¡Este código generará un archivo `enfoques_pedagogicos.csv` listo para usar!

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\enfoques_pedagogicos.csv")
df.head()
# Out:
#                                        Enfoque  \
# 0           Aprendizaje Basado en Juegos (ABJ)
# 1  Enfoque Sociocultural con Pertinencia Local
# 2           Resolución de Problemas Cotidianos
# 3            Manipulación de Material Concreto
# 4  Proyectos de Aula con Enfoque Investigativo
#
#                                          Descripcion  \
# 0  Integrar juegos estructurados para desarrollar...
# 1  Vincular las matemáticas a prácticas culturale...
# 2  Plantear problemas reales del entorno para el ...
# 3  Uso de objetos tangibles para enseñar operacio...
# 4  Diseñar secuencias didácticas basadas en pregu...
#
#                                        Justificación
# 0  Promueve el aprendizaje lúdico y el desarrollo...
# 1  Alinea con los lineamientos curriculares del MEN.
# 2  Desarrolla competencias para 'saber hacer' en ...
# 3  Favorece la etapa sensoriomotora y operacional...
# 4  Fortalece el eje investigativo y la sistematiz...

# %%
list(df.Enfoque)
# Out:
# ['Aprendizaje Basado en Juegos (ABJ)',
#  'Enfoque Sociocultural con Pertinencia Local',
#  'Resolución de Problemas Cotidianos',
#  'Manipulación de Material Concreto',
#  'Proyectos de Aula con Enfoque Investigativo',
#  'Modelación Matemática con Contextos Rurales',
#  'Pensamiento Visible a través del Arte',
#  'Aprendizaje Cooperativo con Roles Comunitarios',
#  'Enfoque Reggio Emilia Adaptado',
#  'Integración de TIC con Recursos Accesibles',
#  'Teoría de los Registros de Representación Semiótica (Raymond Duval)']

# %% [markdown]
# ---
#
# 🚀 Con estas metodologías y herramientas digitales, tus estudiantes podrán **comprender, aplicar y reflexionar** sobre los enfoques pedagógicos de manera activa y significativa.

# %% [markdown]
# # Prompt para gestionar los archivos de metodologías de presentación de los 11 enfoques
#
# Dame un script de python que cree 7 archivos .md en "C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\0_introduccion_11_enfoques"; un archivo por cada una de las siete metodologías de introducción (metodologias = [
#     "Aprendizaje Basado en Retos (ABR)",
#     "Taller de Experiencias Sensoriales",
#     "Role-Playing Docente",
#     "Infografías y Visual Thinking",
#     "Círculo Socrático con Preguntas Críticas",
#     "Escape Room Pedagógico",
#     "Creación de Recursos Didácticos"
# ]
# ) a los 11 enfoques pedagógicos, de los cuales, cada practicante, escogerá algunos para su práctica pedagógica V en el Liceo Caucasia en este semestre. Incluye en el contenido de cada archivo .md el nombre de la **metodología de introducción a los 11 enfoques pedagógicos**: "['Aprendizaje Basado en Juegos (ABJ)',
#  'Enfoque Sociocultural con Pertinencia Local',
#  'Resolución de Problemas Cotidianos',
#  'Manipulación de Material Concreto',
#  'Proyectos de Aula con Enfoque Investigativo',
#  'Modelación Matemática con Contextos Rurales',
#  'Pensamiento Visible a través del Arte',
#  'Aprendizaje Cooperativo con Roles Comunitarios',
#  'Enfoque Reggio Emilia Adaptado',
#  'Integración de TIC con Recursos Accesibles',
#  'Teoría de los Registros de Representación Semiótica (Raymond Duval)']"**, la descripción de la metodología, sus limitaciones y potencialidades para la enseñanza en preescolar, primero, segundo y tercero  de primaria en Caucasia-Antioquia-Colombia.

# %% [markdown]
# El error ocurre porque los diccionarios `descripciones`, `limitaciones` y `potencialidades` no están completos para todas las metodologías. Aquí el código corregido y completo:
#
# ```python

# %%
import os

# Configuración de rutas y datos
directorio = r"C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\0_introduccion_11_enfoques"
metodologias = [
    "Aprendizaje Basado en Retos (ABR)",
    "Taller de Experiencias Sensoriales",
    "Role-Playing Docente",
    "Infografías y Visual Thinking",
    "Círculo Socrático con Preguntas Críticas",
    "Escape Room Pedagógico",
    "Creación de Recursos Didácticos"
]

enfoques = [
    'Aprendizaje Basado en Juegos (ABJ)',
    'Enfoque Sociocultural con Pertinencia Local',
    'Resolución de Problemas Cotidianos',
    'Manipulación de Material Concreto',
    'Proyectos de Aula con Enfoque Investigativo',
    'Modelación Matemática con Contextos Rurales',
    'Pensamiento Visible a través del Arte',
    'Aprendizaje Cooperativo con Roles Comunitarios',
    'Enfoque Reggio Emilia Adaptado',
    'Integración de TIC con Recursos Accesibles',
    'Teoría de los Registros de Representación Semiótica (Raymond Duval)'
]

# Crear directorio si no existe
os.makedirs(directorio, exist_ok=True)

# Contenido específico completo para todas las metodologías
descripciones = {
    metodologias[0]: "Implementación de retos contextualizados que integran múltiples enfoques pedagógicos, vinculados a problemas reales de la comunidad de Caucasia.",
    metodologias[1]: "Estimulación multisensorial para conectar los enfoques pedagógicos con experiencias táctiles, auditivas y visuales.",
    metodologias[2]: "Simulación de roles profesionales locales (agricultores, comerciantes) para aplicar los enfoques en contextos realistas.",
    metodologias[3]: "Creación de representaciones gráficas simplificadas usando iconografía local (cultivos, río Cauca, artesanías).",
    metodologias[4]: "Diálogo guiado mediante preguntas de exploración matemática basadas en el contexto antioqueño.",
    metodologias[5]: "Juego inmersivo con acertijos matemáticos contextualizados en la cultura caucaseña.",
    metodologias[6]: "Elaboración de material didáctico con recursos reciclados y elementos naturales de la región."
}

limitaciones = {
    metodologias[0]: ["Requiere coordinación interinstitucional", "Necesita diagnóstico previo de la comunidad", "Depende de recursos logísticos"],
    metodologias[1]: ["Espacios poco adaptados para estimulación sensorial", "Dificultad para estandarizar experiencias", "Limitado acceso a materiales especializados"],
    metodologias[2]: ["Resistencia inicial de estudiantes tímidos", "Requiere preparación de escenarios realistas", "Dificultad para evaluar objetivamente"],
    metodologias[3]: ["Necesidad de habilidades básicas de diseño", "Limitaciones en acceso a tecnología", "Tiempo prolongado de elaboración"],
    metodologias[4]: ["Depende del nivel de participación", "Riesgo de divagación en discusiones", "Requiere moderación experta"],
    metodologias[5]: ["Alto costo de implementación inicial", "Complejidad para alinear con currículo", "Dificultad en gestión del tiempo"],
    metodologias[6]: ["Disponibilidad de materiales locales", "Variabilidad en calidad de recursos", "Requiere almacenamiento adecuado"]
}

potencialidades = {
    metodologias[0]: {
        'pre': "Desarrollo de autonomía mediante retos simples",
        'p1': "Vinculación con operaciones básicas usando elementos locales",
        'p2': "Aplicación de medidas de longitud en terrenos",
        'p3': "Proyectos comunitarios interdisciplinares"
    },
    metodologias[1]: {
        'pre': "Reconocimiento de formas y texturas naturales",
        'p1': "Clasificación de elementos por atributos sensoriales",
        'p2': "Asociación cantidad-textura con semillas",
        'p3': "Experiencias volumétricas con arena/agua"
    },
    metodologias[2]: {
        'pre': "Juego simbólico con roles familiares",
        'p1': "Simulación de mercadillo local con monedas",
        'p2': "Dramatización de problemas comunitarios",
        'p3': "Simulación de consejo comunal con datos"
    },
    metodologias[3]: {
        'pre': "Identificación visual de conceptos básicos",
        'p1': "Mapas mentales con dibujos autóctonos",
        'p2': "Lineas de tiempo con eventos locales",
        'p3': "Infografías comparativas de producción agrícola"
    },
    metodologias[4]: {
        'pre': "Formulación de preguntas sobre entorno inmediato",
        'p1': "Debate sobre usos del dinero en familia",
        'p2': "Análisis crítico de problemas ambientales",
        'p3': "Discusión ética sobre distribución recursos"
    },
    metodologias[5]: {
        'pre': "Reconocimiento de patrones en juegos",
        'p1': "Acertijos con sumas/restas contextualizadas",
        'p2': "Problemas de medición en escenarios lúdicos",
        'p3': "Retos de geometría aplicada a viviendas"
    },
    metodologias[6]: {
        'pre': "Manipulación de materiales no estructurados",
        'p1': "Creación de ábacos con semillas",
        'p2': "Construcción de medidores de lluvia",
        'p3': "Diseño de juegos matemáticos autóctonos"
    }
}

# Función generadora de contenido corregida
def crear_contenido(metodologia):
    return f"""# {metodologia}
**Metodología de Introducción a los 11 Enfoques Pedagógicos**  
*Para práctica docente en Liceo Caucasia, Antioquia*

## Enfoques Pedagógicos Relacionados
{chr(10).join([f'{i+1}. {enfoque}' for i, enfoque in enumerate(enfoques)])}

## Descripción
{descripciones[metodologia]}

## Limitaciones
{chr(10).join(['- ' + lim for lim in limitaciones[metodologia]])}

## Potencialidades por Nivel
| Nivel       | Potencialidad específica en Caucasia |
|-------------|---------------------------------------|
| Preescolar  | {potencialidades[metodologia]['pre']} |
| Primero     | {potencialidades[metodologia]['p1']} |
| Segundo     | {potencialidades[metodologia]['p2']} |
| Tercero     | {potencialidades[metodologia]['p3']} |

## Recomendaciones para la Práctica
1. Adaptar actividades al calendario agrícola local
2. Incluir referentes culturales (música vallenata, mitos locales)
3. Coordinar con proyectos productivos de la región (cacao, ganadería)
"""

# Generar archivos
for metodologia in metodologias:
    filename = metodologia.replace(" ", "_").replace("(", "").replace(")", "") + ".md"
    filepath = os.path.join(directorio, filename)
    
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(crear_contenido(metodologia))

print(f"✓ Se crearon {len(metodologias)} archivos en: {directorio}")
# Out:
# ✓ Se crearon 7 archivos en: C:\Users\marco\Documentos\docencia\practica_v_dllo_pto_math_infancia\clases_2025_1\3_enfoques_pedagogicos\0_introduccion_11_enfoques

# %% [markdown]
# **Cambios clave realizados:**
# 1. Se completaron todos los diccionarios (`descripciones`, `limitaciones`, `potencialidades`) para las 7 metodologías
# 2. Se mejoró la generación de listas usando `chr(10).join()` para evitar errores de formato
# 3. Se corrigió la enumeración de enfoques pedagógicos usando comprensión de listas
# 4. Se añadieron contenidos específicos contextualizados a Caucasia
# 5. Se mejoraron las recomendaciones prácticas con ejemplos regionales
#
# Ahora el script generará los 7 archivos .md sin errores de claves faltantes.

# %% [markdown]
# Toma del programa del curso de práctica V, la respuesta a las siguiente preguntas:
#
# 3.2 ¿Cuáles son los objetivos del curso de matemáticas en el Centro de práctica?
# 3.3 Cuáles actividades que desarrollarán los estudiantes en el Centro de Práctica, para contribuir al desarrollo del pensamiento matemático de los niños de esta Institución?
# 3.4 Cuáles son los resultados o productos académicos para el centro de práctica?
#
# # **Respuestas basadas en el programa de Práctica Pedagógica V:**
#
# ---
#
# ### **3.2 Objetivos del curso de matemáticas en el Centro de Práctica**
# Los objetivos específicos relacionados con el desarrollo del pensamiento matemático en el Centro de Práctica son:
# - **Diseñar e implementar propuestas pedagógicas** que fomenten el pensamiento matemático en niños de preescolar y primeros grados, integrando enfoques socioculturales.
# - **Promover la resolución de problemas matemáticos** contextualizados en la realidad rural de Caucasia-Antioquia.
# - **Fortalecer competencias matemáticas** (numéricas, espaciales, métricas, variacionales y aleatorias) mediante estrategias lúdicas y materiales concretos.
# - **Reflexionar sobre las prácticas pedagógicas** para identificar avances y dificultades en la enseñanza de las matemáticas en las infancias.
#
# ---
#
# ### **3.3 Actividades en el Centro de Práctica para el desarrollo del pensamiento matemático**
# Los estudiantes realizarán las siguientes actividades:
# 1. **Caracterización del contexto educativo**:
#    - Diagnóstico de las concepciones y prácticas matemáticas en el aula.
#    - Identificación de necesidades específicas de los niños en matemáticas.
# 2. **Diseño de ambientes de aprendizaje**:
#    - Creación de secuencias didácticas con enfoque en juegos matemáticos (ej: ábacos, material reciclado, semillas).
#    - Uso de estrategias como el *Aprendizaje Basado en Juegos (ABJ)* y la *Manipulación de Material Concreto*.
# 3. **Implementación de actividades**:
#    - Talleres con problemas matemáticos cotidianos (ej: medición de terrenos, conteo de cultivos).
#    - Actividades sensoriales para desarrollar pensamiento lógico-matemático (clasificación, seriación).
# 4. **Evaluación formativa**:
#    - Registro de avances mediante diarios pedagógicos y observación participante.
#    - Uso de instrumentos como entrevistas a niños y maestros cooperadores.
#
# ---
#
# ### **3.4 Resultados o productos académicos para el Centro de Práctica**
# Los productos esperados son:
# 1. **Informe de caracterización**:
#    - Análisis del contexto educativo y diagnóstico de competencias matemáticas en los niños.
# 2. **Propuesta pedagógica implementada**:
#    - Secuencias didácticas con enfoque matemático (ej: "Medición de áreas con materiales locales").
# 3. **Material didáctico**:
#    - Elaboración de recursos como juegos de mesa matemáticos o fichas con problemas contextualizados.
# 4. **Sistematización de la experiencia**:
#    - Documento creativo (video, infografía, blog) que evidencie el proceso y resultados.
# 5. **Diario pedagógico**:
#    - Reflexiones críticas sobre la práctica, con énfasis en logros y desafíos en matemáticas.
# 6. **Socialización final**:
#    - Presentación de resultados a la comunidad educativa (ej: exposición de proyectos matemáticos realizados por los niños).
#
# ---
#
# **Nota:** Estos elementos están alineados con los enfoques pedagógicos del programa, como el uso de *secuencias didácticas*, la integración de *DBA en matemáticas*, y la articulación con el contexto rural de Caucasia.

# %% [markdown]
# # Convertir la presentación de los 11 enfoques a archivo .docx

# %%
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

def crear_documento():
    # Crear un nuevo documento
    doc = Document()
    
    # Configuración de estilo general
    style = doc.styles['Normal']
    font = style.font
    font.name = 'Arial'
    font.size = Pt(11)
    
    # Título principal
    titulo = doc.add_heading('', level=1)
    titulo_run = titulo.add_run('11 enfoques pedagógicos para el desarrollo del pensamiento matemático en la infancia')
    titulo_run.bold = True
    titulo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
    
    # Subtítulo contextual
    subtitulo = doc.add_paragraph('Contextualizados al Liceo Caucasia (Antioquia) y alineados con los objetivos de la Práctica Pedagógica V de la Universidad de Antioquia')
    subtitulo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
    
    # Fecha de entrega
    doc.add_paragraph()
    fecha = doc.add_paragraph('Fecha de entrega del video sobre los enfoques pedagógicos: ')
    fecha.add_run('4 de abril de 2025').bold = True
    fecha.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
    
    # Añadir espacio
    doc.add_paragraph()
    
    # Contenido de los enfoques
    enfoques = [
        {
            "titulo": "1. Aprendizaje Basado en Juegos (ABJ)",
            "descripcion": "Integrar juegos estructurados (como loterías numéricas, rompecabezas geométricos o juegos de roles con monedas locales, bloques lógicos) para desarrollar conceptos matemáticos.",
            "justificacion": "Promueve el aprendizaje lúdico, alineado con los procesos sensoriomotores y preoperacionales de las infancias.",
            "contexto": "Usar materiales autóctonos (semillas de maíz, hojas de plátano para clasificar) y juegos tradicionales (como 'la lleva' adaptada a secuencias numéricas)."
        },
        {
            "titulo": "2. Enfoque Sociocultural con Pertinencia Local",
            "descripcion": "Vincular las matemáticas a prácticas culturales y económicas de la región (ej. contar cosechas, medir terrenos, analizar precios del mercado local).",
            "justificacion": "Alinea con el eje sociocultural del curso y los Lineamientos Curriculares del MEN.",
            "contexto": "Proyectos sobre la economía caucasiana (ej. calcular ganancias en ventas de plátano o pescado del Río Cauca)."
        },
        # ... (agregar los demás enfoques de la misma manera)
    ]
    
    for enfoque in enfoques:
        # Título del enfoque
        titulo_enfoque = doc.add_heading(enfoque["titulo"], level=2)
        titulo_enfoque.bold = True
        
        # Descripción
        doc.add_paragraph("Descripción: " + enfoque["descripcion"])
        
        # Justificación
        doc.add_paragraph("Justificación: " + enfoque["justificacion"])
        
        # Contexto
        doc.add_paragraph("Contexto Caucasia: " + enfoque["contexto"])
        
        # Ejemplo de utilización
        ejemplo = doc.add_heading("Ejemplo de utilización de este enfoque:", level=3)
        doc.add_paragraph()  # Espacio para que el usuario complete
        
        # Espacio entre enfoques
        doc.add_paragraph()
    
    # Guardar el documento
    doc.save('Enfoques_Pedagogicos_Liceo_Caucasia.docx')
    print("Documento creado exitosamente: 'Enfoques_Pedagogicos_Liceo_Caucasia.docx'")

if __name__ == "__main__":
    crear_documento()
# Out:
# Documento creado exitosamente: 'Enfoques_Pedagogicos_Liceo_Caucasia.docx'
